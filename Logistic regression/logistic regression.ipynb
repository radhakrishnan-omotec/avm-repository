# %% [markdown]
# Importing all the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Reading the data

# %%
data = pd.read_csv(r'C:\Users\khatr\Downloads\backup\tested.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# Survived: 0 = Dead 1 = Alive
#
# Pclass: 1 = First class 2 = Second class 3 = Third class
#
# Embarked: C = Cherbourg Q = Queenstown S = Southampton

# %% [markdown]
# Data understanding and pre-processing

# %%
data.shape
# Out:
# (418, 12)

# %%
#missing values
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
data['Age'].fillna(data['Age'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
data['Fare'].fillna(data['Fare'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# dtype: int64

# %%
data.drop("Cabin", axis=1, inplace=True)

# %%
print(data.shape)
data.isnull().sum()
# Out:
# (418, 11)
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %%
colname=[]
for x in data.columns:
    if data[x].dtypes=='object':
        colname.append(x)
colname
# Out:
# ['Name', 'Sex', 'Ticket', 'Embarked']

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

for x in colname:
    data[x]=le.fit_transform(data[x])
    le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
    print('Feature', x)
    print('mapping', le_name_mapping)
# Out:
# Feature Name
# mapping {'Abbott, Master. Eugene Joseph': 0, 'Abelseth, Miss. Karen Marie': 1, 'Abelseth, Mr. Olaus Jorgensen': 2, 'Abrahamsson, Mr. Abraham August Johannes': 3, 'Abrahim, Mrs. Joseph (Sophie Halaut Easu)': 4, 'Aks, Master. Philip Frank': 5, 'Aldworth, Mr. Charles Augustus': 6, 'Allison, Mr. Hudson Joshua Creighton': 7, 'Andersen, Mr. Albert Karvin': 8, 'Andersson, Miss. Ida Augusta Margareta': 9, 'Andersson, Mr. Johan Samuel': 10, 'Andrew, Mr. Frank Thomas': 11, 'Angheloff, Mr. Minko': 12, 'Angle, Mr. William A': 13, 'Aronsson, Mr. Ernst Axel Algot': 14, 'Ashby, Mr. John': 15, 'Asplund, Master. Carl Edgar': 16, 'Asplund, Master. Filip Oscar': 17, 'Asplund, Mr. Carl Oscar Vilhelm Gustafsson': 18, 'Asplund, Mr. Johan Charles': 19, 'Assaf Khalil, Mrs. Mariana (Miriam")"': 20, 'Assaf, Mr. Gerios': 21, 'Assam, Mr. Ali': 22, 'Astor, Col. John Jacob': 23, 'Baccos, Mr. Raffull': 24, 'Badman, Miss. Emily Louisa': 25, 'Baimbrigge, Mr. Charles Robert': 26, 'Barry, Miss. Julia': 27, 'Beattie, Mr. Thomson': 28, 'Beauchamp, Mr. Henry James': 29, 'Becker, Miss. Ruth Elizabeth': 30, 'Becker, Mrs. Allen Oliver (Nellie E Baumgardner)': 31, 'Bentham, Miss. Lilian W': 32, 'Betros, Master. Seman': 33, 'Bird, Miss. Ellen': 34, 'Birnbaum, Mr. Jakob': 35, 'Bjorklund, Mr. Ernst Herbert': 36, 'Bonnell, Miss. Caroline': 37, 'Borebank, Mr. John James': 38, 'Botsford, Mr. William Hull': 39, 'Boulos, Master. Akar': 40, 'Bowen, Miss. Grace Scott': 41, 'Bowenur, Mr. Solomon': 42, 'Bradley, Miss. Bridget Delia': 43, 'Brady, Mr. John Bertram': 44, 'Braf, Miss. Elin Ester Maria': 45, 'Brandeis, Mr. Emil': 46, 'Brobeck, Mr. Karl Rudolf': 47, 'Brown, Miss. Edith Eileen': 48, 'Brown, Mrs. John Murray (Caroline Lane Lamson)': 49, 'Bryhl, Miss. Dagmar Jenny Ingeborg ': 50, 'Buckley, Miss. Katherine': 51, 'Buckley, Mr. Daniel': 52, 'Bucknell, Mrs. William Robert (Emma Eliza Ward)': 53, 'Burns, Miss. Mary Delia': 54, 'Cacic, Miss. Manda': 55, 'Cacic, Mr. Jego Grga': 56, 'Caldwell, Mr. Albert Francis': 57, 'Canavan, Mr. Patrick': 58, 'Candee, Mrs. Edward (Helen Churchill Hungerford)': 59, 'Caram, Mr. Joseph': 60, 'Cardeza, Mrs. James Warburton Martinez (Charlotte Wardle Drake)': 61, 'Carlsson, Mr. Carl Robert': 62, 'Carr, Miss. Jeannie': 63, 'Carrau, Mr. Jose Pedro': 64, 'Carver, Mr. Alfred John': 65, 'Case, Mr. Howard Brown': 66, 'Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genevieve Fosdick)': 67, 'Cavendish, Mrs. Tyrell William (Julia Florence Siegel)': 68, 'Chaffee, Mrs. Herbert Fuller (Carrie Constance Toogood)': 69, 'Chapman, Mrs. John Henry (Sara Elizabeth Lawry)': 70, 'Chaudanson, Miss. Victorine': 71, 'Chevre, Mr. Paul Romaine': 72, 'Chisholm, Mr. Roderick Robert Crispin': 73, 'Christy, Mrs. (Alice Frances)': 74, 'Chronopoulos, Mr. Demetrios': 75, 'Clark, Mr. Walter Miller': 76, 'Clark, Mrs. Walter Miller (Virginia McDowell)': 77, 'Clarke, Mr. Charles Valentine': 78, 'Colbert, Mr. Patrick': 79, 'Collett, Mr. Sidney C Stuart': 80, 'Compton, Mr. Alexander Taylor Jr': 81, 'Compton, Mrs. Alexander Taylor (Mary Eliza Ingersoll)': 82, 'Conlon, Mr. Thomas Henry': 83, 'Connolly, Miss. Kate': 84, 'Cook, Mrs. (Selena Rogers)': 85, 'Cor, Mr. Bartol': 86, 'Cor, Mr. Ivan': 87, 'Corbett, Mrs. Walter H (Irene Colvin)': 88, 'Corey, Mrs. Percy C (Mary Phyllis Elizabeth Miller)': 89, 'Cornell, Mrs. Robert Clifford (Malvina Helen Lamson)': 90, 'Cotterill, Mr. Henry Harry""': 91, 'Coutts, Mrs. William (Winnie Minnie" Treanor)"': 92, 'Crafton, Mr. John Bertram': 93, 'Cribb, Miss. Laura Alice': 94, 'Crosby, Mrs. Edward Gifford (Catherine Elizabeth Halstead)': 95, 'Cumings, Mr. John Bradley': 96, 'Daher, Mr. Shedid': 97, 'Daly, Miss. Margaret Marcella Maggie""': 98, 'Danbom, Master. Gilbert Sigvard Emanuel': 99, 'Daniels, Miss. Sarah': 100, 'Davidson, Mrs. Thornton (Orian Hays)': 101, 'Davies, Mr. Evan': 102, 'Davies, Mr. John Samuel': 103, 'Davies, Mr. Joseph': 104, 'Davies, Mrs. John Morgan (Elizabeth Agnes Mary White) ': 105, 'Davison, Mr. Thomas Henry': 106, 'Deacon, Mr. Percy Wil ...
# Feature Sex
# mapping {'female': 0, 'male': 1}
# Feature Ticket
# mapping {'110469': 0, '110489': 1, '110813': 2, '111163': 3, '112051': 4, '112058': 5, '112377': 6, '112378': 7, '112901': 8, '113038': 9, '113044': 10, '113054': 11, '113059': 12, '113503': 13, '113509': 14, '113773': 15, '113778': 16, '113780': 17, '113781': 18, '113790': 19, '113791': 20, '113795': 21, '113796': 22, '113801': 23, '11753': 24, '11765': 25, '11767': 26, '11769': 27, '11770': 28, '11778': 29, '11813': 30, '1222': 31, '12749': 32, '13050': 33, '13236': 34, '13508': 35, '13567': 36, '13695': 37, '13905': 38, '1601': 39, '16966': 40, '17463': 41, '17464': 42, '17475': 43, '17765': 44, '17770': 45, '19877': 46, '19924': 47, '19928': 48, '19950': 49, '2003': 50, '211535': 51, '21228': 52, '21332': 53, '220844': 54, '220845': 55, '226875': 56, '228414': 57, '230136': 58, '233478': 59, '233734': 60, '235509': 61, '236853': 62, '236854': 63, '237216': 64, '237249': 65, '237393': 66, '237670': 67, '237734': 68, '237735': 69, '237789': 70, '239059': 71, '240261': 72, '240276': 73, '24065': 74, '24160': 75, '242963': 76, '244346': 77, '244358': 78, '244360': 79, '244368': 80, '248659': 81, '248726': 82, '248734': 83, '248738': 84, '248744': 85, '248746': 86, '250650': 87, '250651': 88, '2543': 89, '2621': 90, '2622': 91, '2625': 92, '26360': 93, '2650': 94, '2652': 95, '2653': 96, '2654': 97, '2655': 98, '2656': 99, '2657': 100, '2658': 101, '2660': 102, '2661': 103, '2662': 104, '2668': 105, '2670': 106, '26707': 107, '2673': 108, '2675': 109, '2676': 110, '2678': 111, '2679': 112, '2680': 113, '2681': 114, '2682': 115, '2684': 116, '2688': 117, '2689': 118, '2692': 119, '2696': 120, '2698': 121, '28004': 122, '28034': 123, '28133': 124, '28220': 125, '28221': 126, '28404': 127, '28664': 128, '28666': 129, '29103': 130, '29105': 131, '29107': 132, '2926': 133, '29750': 134, '3101266': 135, '3101295': 136, '3101297': 137, '3101298': 138, '315083': 139, '315085': 140, '315087': 141, '315091': 142, '315092': 143, '315095': 144, '315152': 145, '315153': 146, '315154': 147, '32302': 148, '329944': 149, '330844': 150, '330910': 151, '330911': 152, '330920': 153, '330924': 154, '330963': 155, '330968': 156, '330971': 157, '330972': 158, '334914': 159, '334915': 160, '335432': 161, '33638': 162, '3410': 163, '342441': 164, '342684': 165, '342712': 166, '343271': 167, '345498': 168, '345501': 169, '345572': 170, '345763': 171, '345768': 172, '345771': 173, '345775': 174, '3470': 175, '347065': 176, '347066': 177, '347070': 178, '347072': 179, '347075': 180, '347077': 181, '347079': 182, '347080': 183, '347086': 184, '347090': 185, '347091': 186, '347465': 187, '347467': 188, '347469': 189, '347471': 190, '348122': 191, '348125': 192, '349202': 193, '349211': 194, '349220': 195, '349226': 196, '349229': 197, '349230': 198, '349232': 199, '349235': 200, '349238': 201, '349250': 202, '349255': 203, '349256': 204, '349909': 205, '349910': 206, '349911': 207, '350026': 208, '350033': 209, '350045': 210, '350053': 211, '350054': 212, '350403': 213, '350405': 214, '350408': 215, '350409': 216, '350410': 217, '350416': 218, '359306': 219, '359309': 220, '363272': 221, '363611': 222, '364498': 223, '364856': 224, '364858': 225, '364859': 226, '365235': 227, '365237': 228, '36568': 229, '366713': 230, '367226': 231, '367227': 232, '368364': 233, '368402': 234, '368573': 235, '368702': 236, '368783': 237, '36928': 238, '3701': 239, '370129': 240, '370368': 241, '370371': 242, '370374': 243, '371109': 244, '371362': 245, '376563': 246, '376566': 247, '382650': 248, '382652': 249, '382653': 250, '383123': 251, '383162': 252, '386525': 253, '392091': 254, '392095': 255, '4133': 256, '65305': 257, '680': 258, '694': 259, '7266': 260, '7538': 261, '7548': 262, '7935': 263, '9232': 264, 'A. 2. 39186': 265, 'A./5. 3338': 266, 'A.5. 3236': 267, 'A/4 31416': 268, 'A/4 48871': 269, 'A/4 48873': 270, 'A/5 1478': 271, 'A/5 21175': 272, 'A/5. 3337': 273, 'A/5. 851': 274, 'AQ/3. 30631': 275, 'AQ/4 3130': 276, 'C 17368': 277, 'C 4001': 278, 'C.A. 15185': ...
# Feature Embarked
# mapping {'C': 0, 'Q': 1, 'S': 2}

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0          892         0       3   206    1  34.5      0      0     152
# 1          893         1       3   403    0  47.0      1      0     221
# 2          894         0       2   269    1  62.0      0      0      73
# 3          895         0       3   408    1  27.0      0      0     147
# 4          896         1       3   178    0  22.0      1      1     138
#
#       Fare  Embarked
# 0   7.8292         1
# 1   7.0000         2
# 2   9.6875         1
# 3   8.6625         2
# 4  12.2875         2

# %%
X = data[['PassengerId','Pclass','Name','Sex','Age','SibSp','Parch','Ticket','Fare','Embarked']]
Y = data[['Survived']]

# %%
X.shape
# Out:
# (418, 10)

# %%
Y.shape
# Out:
# (418, 1)

# %%
from sklearn.model_selection import train_test_split 

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=10)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (292, 10)
# (292, 1)
# (126, 10)
# (126, 1)

# %%
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression()


classifier.fit(X_train,Y_train)
# Out:
# c:\Users\khatr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\khatr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
Y_pred=classifier.predict(X_test)
# print(Y_pred)
# print(list(zip(Y_test,Y_pred)))

# %%
new_data = pd.DataFrame()
new_data = (X_test)

new_data['Actual'] = Y_test
new_data['Predicted'] = Y_pred

# %%
new_data
# Out:
#      PassengerId  Pclass  Name  Sex       Age  SibSp  Parch  Ticket      Fare  \
# 362         1254       2   387    0  31.00000      0      0     295   21.0000
# 154         1046       3    17    1  13.00000      4      2     181   31.3875
# 47           939       3   345    1  30.27259      0      0     243    7.7500
# 100          992       1   360    0  43.00000      1      0      29   55.4417
# 187         1079       3   104    1  17.00000      2      0     270    8.0500
# ..           ...     ...   ...  ...       ...    ...    ...     ...       ...
# 274         1166       3   330    1  30.27259      0      0     110    7.2250
# 218         1110       1   401    0  50.00000      1      1      13  211.5000
# 29           921       3   339    1  30.27259      2      0     104   21.6792
# 279         1171       2   290    1  22.00000      0      0     358   10.5000
# 278         1170       2   385    1  30.00000      1      0     295   21.0000
#
#      Embarked  Actual  Predicted
# 362         2       1          1
# 154         2       0          0
# 47          1       0          0
# 100         0       1          1
# 187         2       0          0
# ..        ...     ...        ...
# 274         0       0          0
# 218         0       1          1
# 29          0       0          0
# 279         2       0          0
# 278         2       0          0
#
# [126 rows x 12 columns]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

cfm=confusion_matrix(Y_test,Y_pred)
print(cfm)

print("Classification report:")

print(classification_report(Y_test,Y_pred))

acc=accuracy_score(Y_test,Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# [[77  0]
#  [ 0 49]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        77
#            1       1.00      1.00      1.00        49
#
#     accuracy                           1.00       126
#    macro avg       1.00      1.00      1.00       126
# weighted avg       1.00      1.00      1.00       126
#
# Accuracy of the model:  1.0

# %%
print(classifier.coef_)
# Out:
# [[ 3.11236299e-03 -3.07196311e-01 -7.10074206e-04 -6.07753981e+00
#    4.66533354e-04  5.15349920e-02  1.43669764e-01  2.65904613e-03
#    8.49700748e-04 -3.96476444e-01]]

# %%
print(classifier.intercept_)
# Out:
# [0.01545516]

# %%
data.drop("Name", axis=1, inplace=True)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch  Ticket     Fare  \
# 0          892         0       3    1  34.5      0      0     152   7.8292
# 1          893         1       3    0  47.0      1      0     221   7.0000
# 2          894         0       2    1  62.0      0      0      73   9.6875
# 3          895         0       3    1  27.0      0      0     147   8.6625
# 4          896         1       3    0  22.0      1      1     138  12.2875
#
#    Embarked
# 0         1
# 1         2
# 2         1
# 3         2
# 4         2

# %%
X = data[['PassengerId','Pclass','Sex','Age','SibSp','Parch','Ticket','Fare','Embarked']]
Y = data[['Survived']]

# %%
X.shape
# Out:
# (418, 9)

# %%
Y.shape
# Out:
# (418, 1)

# %%
from sklearn.model_selection import train_test_split 

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1,random_state=10)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (376, 9)
# (376, 1)
# (42, 9)
# (42, 1)

# %%
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression()


classifier.fit(X_train,Y_train)
# Out:
# c:\Users\khatr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\khatr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
Y_pred=classifier.predict(X_test)
# print(Y_pred)
# print(list(zip(Y_test,Y_pred)))

# %%
new_data = pd.DataFrame()
new_data = (X_test)

new_data['Actual'] = Y_test
new_data['Predicted'] = Y_pred
new_data
# Out:
#      PassengerId  Pclass  Sex       Age  SibSp  Parch  Ticket        Fare  \
# 362         1254       2    0  31.00000      0      0     295   21.000000
# 154         1046       3    1  13.00000      4      2     181   31.387500
# 47           939       3    1  30.27259      0      0     243    7.750000
# 100          992       1    0  43.00000      1      0      29   55.441700
# 187         1079       3    1  17.00000      2      0     270    8.050000
# 114         1006       1    0  63.00000      1      0     303  221.779200
# 236         1128       1    1  64.00000      1      0       2   75.250000
# 142         1034       1    1  61.00000      1      3     319  262.375000
# 396         1288       3    1  24.00000      0      0     244    7.250000
# 1            893       3    0  47.00000      1      0     221    7.000000
# 192         1084       3    1  11.50000      1      1     274   14.500000
# 110         1002       2    1  41.00000      0      0      68   15.045800
# 43           935       2    0  30.00000      0      0      65   13.000000
# 264         1156       2    1  30.00000      0      0     288   12.737500
# 308         1200       1    1  55.00000      1      1      32   93.500000
# 277         1169       2    1  40.00000      1      0     133   26.000000
# 184         1076       1    0  27.00000      1      1     305  247.520800
# 65           957       2    0  30.27259      0      0     300   21.000000
# 97           989       3    1  29.00000      0      0     354    7.925000
# 78           970       2    1  30.00000      0      0      85   13.000000
# 324         1216       1    0  39.00000      0      0      75  211.337500
# 166         1058       1    1  48.00000      0      0     310   50.495800
# 24           916       1    0  48.00000      1      3     319  262.375000
# 121         1013       3    1  30.27259      1      0     232    7.750000
# 161         1053       3    1   7.00000      1      1      94   15.245800
# 282         1174       3    0  30.27259      0      0     226    7.750000
# 280         1172       3    0  23.00000      0      0     140    8.662500
# 222         1114       2    0  22.00000      0      0     359   10.500000
# 293         1185       1    1  53.00000      1      1     162   81.858300
# 263         1155       3    0   1.00000      1      1     214   12.183300
# 175         1067       2    0  15.00000      0      2     134   39.000000
# 225         1117       3    0  30.27259      0      2     103   15.245800
# 345         1237       3    0  16.00000      0      0     192    7.650000
# 247         1139       2    1  42.00000      1      1     125   32.500000
# 126         1018       3    1  22.00000      0      0     210    7.795800
# 146         1038       1    1  30.27259      0      0      41   51.862500
# 188         1080       3    0  30.27259      8      2     296   69.550000
# 296         1188       2    0   1.00000      1      2     345   41.579200
# 212         1104       2    1  17.00000      0      0     333   73.500000
# 105          997       3    1  28.00000      0      0     278   22.525000
# 367         1259       3    0  22.00000      0      0     136   39.687500
# 152         1044       3    1  60.50000      0      0     239   35.627188
#
#      Embarked  Actual  Predicted
# 362         2       1          1
# 154         2       0          0
# 47          1       0          0
# 100         0       1          1
# 187         2       0          0
# 114         2       1          1
# 236         0       0          0
# 142         0       0          0
# 396         1       0          0
# 1           2       1          1
# 192         2       0          0
# 110         0       0          0
# 43          2       1          1
# 264         0       0          0
# 308         2       0          0
# 277         2       0          0
# 184         0       1          1
# 65          2       1          1
# 97          2       0          0
# 78          2       0          0
# 324         2       1          1
# 166         0       0          0
# 24          0       1          1
# 121         1       0          0
# 161         0       0          0
# 282         1       1          1
# 280         2       1          1
# 222         2       1          1
# 293         2       0          0
# 263         2       1          1
# 175         2       1          1
# 225         0       1          1
# 345         2       1          1
# 247         2       0          0
# 126         2       0          0
# 146         2       0          0
# 188         2       1          1
# 296         0       1          1
# 212         2       0          0
# 105         2       0          0
# 367         2       1          1
# 152         2       0          0

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

cfm=confusion_matrix(Y_test,Y_pred)
print(cfm)

print("Classification report:")

print(classification_report(Y_test,Y_pred))

acc=accuracy_score(Y_test,Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# [[23  0]
#  [ 0 19]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00        19
#
#     accuracy                           1.00        42
#    macro avg       1.00      1.00      1.00        42
# weighted avg       1.00      1.00      1.00        42
#
# Accuracy of the model:  1.0

# %%
print(classifier.coef_)
# Out:
# [[ 2.30619130e-03 -2.51539050e-03 -6.61400143e+00  6.11183242e-04
#    6.54395628e-02  1.39030055e-01  6.48450866e-04  3.76892679e-03
#   -4.69288581e-02]]

# %%
print(classifier.intercept_)
# Out:
# [0.0932576]

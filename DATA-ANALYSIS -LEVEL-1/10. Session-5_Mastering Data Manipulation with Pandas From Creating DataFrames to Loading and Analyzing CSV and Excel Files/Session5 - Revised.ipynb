# %% [markdown]
# # SESSION 5

# %% [markdown]
# 1. Dataset, Series & Dataframe
# 2. Creating a DataFrame
# 3. Loading files into a DataFrame<br>
# 	3.1 Reading in DataFrame<br>
# 	3.2 DataFrame head() Function<br>
# 	3.3 DataFrame tail() Function<br>
# 	3.4 Information About the DataSet<br>
# 4. Read CSV in Pandas<br>
#     4.1 Read Sample CSV:<br>
#     4.2 To check maximum number of rows<br>
#     4.3 Read a CSV file and print the first few rows using the head() method:<br>
#     4.4 Read a CSV file and print the Last few rows using the tail() method:<br>
#     4.5 Pandas describe() method on CSV Files<br>
#     4.6 Writing a Pandas DataFrame to CSV file<br>
# 5. Read Excel in Pandas<br>
#     5.1 Install xlrd<br>
#     5.2 Load multiple sheets<br>
#     5.3 Display List of Columns Headers of the Excel Sheet<br>
#     5.4 Pandas read_excel() usecols example<br>

# %% [markdown]
# ## 1. Dataset, Series & Dataframe

# %% [markdown]
# - Dataset : a general term that refers to any collection of data. In pandas, it usually refers to a collection of data that is stored in memory and can be accessed and manipulated using the pandas library.
# - Series : a one-dimensional array-like data structure, similar to a column in a spreadsheet.
# - DataFrame : a two-dimensional table-like data structure consisting of rows and columns, similar to a spreadsheet.

# %% [markdown]
# <img align = 'middle' src = 'Images/Intro-pandas-dataframe.png' width = 700>

# %% [markdown]
# <hr>

# %% [markdown]
# ## 2. Creating a DataFrame

# %% [markdown]
# **We can create a DataFrame using :**
#
# - Lists
# - Dictionaries
# - NumPy Arrays
# - Series

# %%
# Create an empty DataFrame

# importing the pandas library 
 
import pandas as pd  
df = pd.DataFrame()  
print (df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# **Creating a DataFrame using a List :**

# %%
# importing the pandas library 
import pandas as pd 
 
# Create a list of strings  
x = ['Python', 'Pandas']  
  
# Calling Data Frame constructor & passing it the created list
df = pd.DataFrame(x)  
print(df)
# Out:
#         0
# 0  Python
# 1  Pandas

# %% [markdown]
# ![Untitled%20Diagram%20%2826%29.jpg](attachment:Untitled%20Diagram%20%2826%29.jpg)

# %% [markdown]
# **Creating a DataFrame using a Dictionary of lists :**

# %%
# importing the pandas library  
import pandas as pd  

# Create a Dictionary of lists 
info = {'ID' :[101, 102, 103],'  Department' :['B.Sc','B.Tech','M.Tech']} 

# Calling Data Frame constructor & passing it the created dictionary
df = pd.DataFrame(info)  
print (df)
# Out:
#     ID   Department
# 0  101         B.Sc
# 1  102       B.Tech
# 2  103       M.Tech

# %% [markdown]
# **Creating a DataFrame using a Dictionary of Series :**

# %%
# importing the pandas library  
import pandas as pd  

# Create a Dictionary of Series
# The number of indexes should be equal to the number of elements in the Series
info = {'one' : pd.Series([1, 2, 3, 4, 5, 6], index=['a', 'b', 'c', 'd', 'e', 'f']),  
   'two' : pd.Series([1, 2, 3, 4, 5, 6, 7, 8], index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])}  

# Calling Data Frame constructor & passing it the created dictionary
d1 = pd.DataFrame(info)  
print (d1)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  4.0    4
# e  5.0    5
# f  6.0    6
# g  NaN    7
# h  NaN    8

# %% [markdown]
# **Column Selection on a DataFrame :**

# %%
# We can select any column from the DataFrame, Here is the code that demonstrates how to select a column from the DataFrame.

# importing the pandas library  
import pandas as pd  

# Create a Dictionary of Series
info = {'one' : pd.Series([1, 2, 3, 4, 5, 6], index=['a', 'b', 'c', 'd', 'e', 'f']),  
   'two' : pd.Series([1, 2, 3, 4, 5, 6, 7, 8], index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])}  

# Calling Data Frame constructor & passing it the created dictionary
d1 = pd.DataFrame(info) 

# Select a column from the created DataFrame 
print (d1 ['one'])
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# f    6.0
# g    NaN
# h    NaN
# Name: one, dtype: float64

# %% [markdown]
# **Adding columns to a DataFrame :**

# %%
# We can also add a new column to an existing DataFrame. The below code demonstrates how to add a new column to an existing DataFrame

# importing the pandas library  
import pandas as pd  
  
# Create a Dictionary of Series
info = {'one' : pd.Series([1, 2, 3, 4, 5], index=['a', 'b', 'c', 'd', 'e']),  
   'two' : pd.Series([1, 2, 3, 4, 5, 6], index=['a', 'b', 'c', 'd', 'e', 'f'])}  

# Calling Data Frame constructor & passing it the created dictionary
df = pd.DataFrame(info)  
  
# Adding a new column to an existing DataFrame object   
print ("Add a new column by passing a Series")  
df['three'] = pd.Series([20, 40, 60], index=['a', 'b', 'c'])   
print (df)
# Out:
# Add a new column by passing a Series
#    one  two  three
# a  1.0    1   20.0
# b  2.0    2   40.0
# c  3.0    3   60.0
# d  4.0    4    NaN
# e  5.0    5    NaN
# f  NaN    6    NaN

# %% [markdown]
# **Deleting columns from a DataFrame :**

# %%
# Column Deletion:
# We can also delete any column from an existing DataFrame. This code helps to demonstrate how we can delete a column from an existing DataFrame

# importing the pandas library  
import pandas as pd  
  
info = {'one' : pd.Series([1, 2], index= ['a', 'b']),   
   'two' : pd.Series([1, 2, 3], index=['a', 'b', 'c'])}  
     
df = pd.DataFrame(info)  
print ("The DataFrame:")  
print (df)  
  
# Deleting a column using del function  
print ("Delete the first column:")  
del df['one']  
print (df)  

# Deleting a column using pop function  
print ("Delete the other column:")  
df.pop('two')  
print (df)
# Out:
# The DataFrame:
#    one  two
# a  1.0    1
# b  2.0    2
# c  NaN    3
# Delete the first column:
#    two
# a    1
# b    2
# c    3
# Delete the other column:
# Empty DataFrame
# Columns: []
# Index: [a, b, c]

# %% [markdown]
# **Performing operations on rows of a DataFrame :**
# - We can easily select, add, or delete any row from a DataFrame. First of all, we will understand the row selection. Let's see how we can select a row using different ways that are as follows :
#
# **1) Selecting a row by Indexing :**
#
# - We can select any row by passing the row index to a loc function.

# %%
# importing the pandas library  
import pandas as pd  
  
info = {'one' : pd.Series([1, 2, 3, 4, 5], index=['a', 'b', 'c', 'd', 'e']),   
   'two' : pd.Series([6, 7, 8, 9, 10, 11], index=['a', 'b', 'c', 'd', 'e', 'f'])}  
  
df = pd.DataFrame(info)  
print(df)

# Passing a row index to the loc function 
print (df.loc['b'])
# Out:
#    one  two
# a  1.0    6
# b  2.0    7
# c  3.0    8
# d  4.0    9
# e  5.0   10
# f  NaN   11
# one    2.0
# two    7.0
# Name: b, dtype: float64

# %% [markdown]
# **2) Selecting a row by Slicing :**

# %%
# Slicing is another method to select multiple rows using ':' operator.

# importing the pandas library  
import pandas as pd  

info = {'one' : pd.Series([1, 2, 3, 4, 5], index=['a', 'b', 'c', 'd', 'e']),   
   'two' : pd.Series([1, 2, 3, 4, 5, 6], index=['a', 'b', 'c', 'd', 'e', 'f'])} 
 
df = pd.DataFrame(info) 

# Slicing the DataFrame (similar to slicing a list)
print (df[2:5])
# Out:
#    one  two
# c  3.0    3
# d  4.0    4
# e  5.0    5

# %% [markdown]
# **3) Adding new rows to a DataFrame :**
# - We can easily add new rows to a DataFrame using the ```append()``` function. It adds new rows at the end of the DataFrame.
# - The append method of a DataFrame in pandas is used to append rows of another DataFrame to the end of the original DataFrame.

# %%
import pandas as pd

info = {'one' : pd.Series([1, 2, 3, 4, 5], index=['a', 'b', 'c', 'd', 'e']),   
   'two' : pd.Series([1, 2, 3, 4, 5, 6], index=['a', 'b', 'c', 'd', 'e', 'f'])} 
 
df = pd.DataFrame(info) 

# create a new row
new_row = { 'one': 6, 'two' : 7}

# append the new row to the DataFrame
df = df.append(new_row, ignore_index=True)

# print the updated DataFrame
print(df)
# Out:
#    one  two
# 0  1.0    1
# 1  2.0    2
# 2  3.0    3
# 3  4.0    4
# 4  5.0    5
# 5  NaN    6
# 6  6.0    7

# %%
import pandas as pd

# Create the original DataFrame
df1 = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})

# Create the second DataFrame to append
df2 = pd.DataFrame({'A': [5, 6], 'B': [7, 8]})

# Append df2 to df1
df3 = df1.append(df2)

print(df3)
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 0  5  7
# 1  6  8

# %% [markdown]
# **Note : The frame.append method will be removed from pandas in it's future version. So use pandas.concat instead.**

# %% [markdown]
# - The ```concat()``` function in pandas is used to concatenate two or more DataFrames into a single DataFrame.

# %%
import pandas as pd

# Create the first DataFrame
df1 = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})

# Create the second DataFrame
df2 = pd.DataFrame({'C': [5, 6], 'D': [7, 8]})

# Concatenate the two DataFrames along the rows
result = pd.concat([df1, df2], axis=0)

print(result)
# Out:
#      A    B    C    D
# 0  1.0  3.0  NaN  NaN
# 1  2.0  4.0  NaN  NaN
# 0  NaN  NaN  5.0  7.0
# 1  NaN  NaN  6.0  8.0

# %% [markdown]
# **4) Locating Rows of a DataFrame :**
# - We can use the loc attribute to return one or more specified row(s) of a DataFrame

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

# load data into a DataFrame object:
df = pd.DataFrame(data)
print(df)

print(df.loc[2]) # elements in the row at index 2 will be returned
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
# calories    390
# duration     45
# Name: 2, dtype: int64

# %%
# Accessing elements of multiple rows :

# Use a list of indexes:
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

# Load data into the DataFrame object:
df = pd.DataFrame(data)

# Accessing elements of rows 0 & 1 :
print(df.loc[[0, 1]])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %% [markdown]
# **Named Indexes : With the ```index``` argument, you can name your own indexes**

# %%
# Add a list of names to give each row a name :

import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %% [markdown]
# <hr>

# %% [markdown]
# ## 3. Operations in DataFrame

# %% [markdown]
# #### 3.1 Reading in DataFrame

# %% [markdown]
# **3.2 DataFrame ```head()``` Function**

# %% [markdown]
# - The head() returns the first n rows for the object based on position.
# - If your object has the right type of data in it, it is useful for quick testing.
# - This method is used for returning top n (by default value 5) rows of a data frame or series.

# %%
import pandas as pd

# head() Function in DataFrame

info1 = pd.DataFrame({'language':['C#', 'C++', 'Python', 'Java','PHP']})  
info1.head()  
info1.head(3)
# Out:
#   language
# 0       C#
# 1      C++
# 2   Python

# %% [markdown]
# **3.3 DataFrame ```tail()``` Function**
#
# - The ```tail()``` method returns the headers and a specified number of rows, starting from the bottom.

# %%
import pandas as pd    

# making data frame   
data = pd.read_csv("Images\largedata.csv")    
 
# calling tail() method    
# storing in new variable   
data_bottom  = data.tail(2)    
# display   
data_bottom
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 6193     BDCQ.SF8RSCA  2022.06     579.955        NaN      R  Dollars
# 6194     BDCQ.SF8RSCA  2022.09     609.161        NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 6193          6  Business Data Collection - BDC
# 6194          6  Business Data Collection - BDC
#
#                                                 Group    Series_title_1  \
# 6193  Industry by financial variable (NZSIOC Level 1)  Operating profit
# 6194  Industry by financial variable (NZSIOC Level 1)  Operating profit
#
#                            Series_title_2 Series_title_3 Series_title_4  \
# 6193  Arts, Recreation and Other Services        Current     Unadjusted
# 6194  Arts, Recreation and Other Services        Current     Unadjusted
#
#       Series_title_5
# 6193             NaN
# 6194             NaN

# %% [markdown]
# **3.4 Information About the DataSet**
# -  DataFrames object has a method called ```info()```, that gives more information about the data set.

# %%
import pandas as pd

data = pd.read_csv("Images\largedata.csv")    
data.head()

print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6195 entries, 0 to 6194
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Series_reference  6195 non-null   object
#  1   Period            6195 non-null   float64
#  2   Data_value        5720 non-null   float64
#  3   Suppressed        15 non-null     object
#  4   STATUS            6195 non-null   object
#  5   UNITS             6195 non-null   object
#  6   Magnitude         6195 non-null   int64
#  7   Subject           6195 non-null   object
#  8   Group             6195 non-null   object
#  9   Series_title_1    6195 non-null   object
#  10  Series_title_2    6195 non-null   object
#  11  Series_title_3    6195 non-null   object
#  12  Series_title_4    6195 non-null   object
#  13  Series_title_5    0 non-null      float64
# dtypes: float64(3), int64(1), object(10)
# memory usage: 677.7+ KB
# None

# %% [markdown]
# <hr>

# %% [markdown]
# ## 3.5 Loading files into a DataFrame
# - If your data sets are stored in a file, Pandas can load them into a DataFrame.

# %%
# Load a comma separated file (CSV file) into a DataFrame :

import pandas as pd

df = pd.read_csv('Images/data.csv')

print(df)
# Out:
#    Student ID First Name Last Name                  Email  GPA Enrollment Date
# 0           1       John       Doe     john.doe@email.com  3.7      2020-09-01
# 1           2       Jane     Smith   jane.smith@email.com  3.9      2020-09-01
# 2           3        Bob   Johnson  bob.johnson@email.com  3.2      2020-09-01
# 3           4      Sarah       Lee    sarah.lee@email.com  3.5      2020-09-01
# 4           5      David      Wong   david.wong@email.com  3.8      2020-09-01

# %% [markdown]
# <br>
# <img src="images/Image-csv.png" alt="Drawing" style="width: 600px;" align="center"/>
# <br>
# <br>

# %% [markdown]
# <hr>

# %% [markdown]
# ## 4. Read CSV in Pandas
#
# - A simple way to store big data sets is to use CSV files (comma separated files).
#
# - CSV files contains plain text and is a well known format that can be read by everyone including Pandas.
#
# - In our example, we will be using a CSV file called 'data.csv'.
#
# - Download data.csv or Open data.csv

# %% [markdown]
# **4.1 Read Sample CSV:**

# %%
import pandas as pd

df = pd.read_csv('Images/data.csv')

print(df.to_string())
# Out:
#    Student ID First Name Last Name                  Email  GPA Enrollment Date
# 0           1       John       Doe     john.doe@email.com  3.7      2020-09-01
# 1           2       Jane     Smith   jane.smith@email.com  3.9      2020-09-01
# 2           3        Bob   Johnson  bob.johnson@email.com  3.2      2020-09-01
# 3           4      Sarah       Lee    sarah.lee@email.com  3.5      2020-09-01
# 4           5      David      Wong   david.wong@email.com  3.8      2020-09-01

# %% [markdown]
# <br>
# <img src="images/Image-text.png" alt="Drawing" style="width: 400px;" align="center"/>
# <img src="images/Image-csv.png" alt="Drawing" style="width: 600px;" align="center"/>
# <br>
# <br>

# %%
# Print the DataFrame without the to_string() method :

import pandas as pd

df = pd.read_csv('Images/data.csv')

print(df)
# Out:
#    Student ID First Name Last Name                  Email  GPA Enrollment Date
# 0           1       John       Doe     john.doe@email.com  3.7      2020-09-01
# 1           2       Jane     Smith   jane.smith@email.com  3.9      2020-09-01
# 2           3        Bob   Johnson  bob.johnson@email.com  3.2      2020-09-01
# 3           4      Sarah       Lee    sarah.lee@email.com  3.5      2020-09-01
# 4           5      David      Wong   david.wong@email.com  3.8      2020-09-01

# %% [markdown]
# **4.2 To check maximum number of rows**
# - The number of rows returned is defined in Pandas option settings.
#
# - You can check your system's maximum rows with the pd.options.display.max_rows statement.

# %%
# Check the number of maximum returned rows :

import pandas as pd

print(pd.options.display.max_rows)
# Out:
# 60

# %%
# Increasing the maximum number of rows to display the entire DataFrame :
import pandas as pd

pd.options.display.max_rows = 9999

df = pd.read_csv('Images/largedata.csv')

print(df)
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars
# 1       BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars
# 2       BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars
# 3       BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars
# 4       BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars
# 5       BDCQ.SF1AA2CA  2017.09    1282.436        NaN      F  Dollars
# 6       BDCQ.SF1AA2CA  2017.12    1290.820        NaN      F  Dollars
# 7       BDCQ.SF1AA2CA  2018.03    1412.007        NaN      F  Dollars
# 8       BDCQ.SF1AA2CA  2018.06    1488.055        NaN      F  Dollars
# 9       BDCQ.SF1AA2CA  2018.09    1497.678        NaN      F  Dollars
# 10      BDCQ.SF1AA2CA  2018.12    1570.507        NaN      F  Dollars
# 11      BDCQ.SF1AA2CA  2019.03    1393.749        NaN      F  Dollars
# 12      BDCQ.SF1AA2CA  2019.06    1517.143        NaN      F  Dollars
# 13      BDCQ.SF1AA2CA  2019.09    1381.514        NaN      F  Dollars
# 14      BDCQ.SF1AA2CA  2019.12    1370.985        NaN      F  Dollars
# 15      BDCQ.SF1AA2CA  2020.03    1073.017        NaN      F  Dollars
# 16      BDCQ.SF1AA2CA  2020.06    1131.445        NaN      F  Dollars
# 17      BDCQ.SF1AA2CA  2020.09    1440.101        NaN      F  Dollars
# 18      BDCQ.SF1AA2CA  2020.12    1489.979        NaN      F  Dollars
# 19      BDCQ.SF1AA2CA  2021.03    1390.782        NaN      F  Dollars
# 20      BDCQ.SF1AA2CA  2021.06    1826.730        NaN      F  Dollars
# 21      BDCQ.SF1AA2CA  2021.09    1710.073        NaN      F  Dollars
# 22      BDCQ.SF1AA2CA  2021.12    1559.479        NaN      F  Dollars
# 23      BDCQ.SF1AA2CA  2022.03    1285.083        NaN      F  Dollars
# 24      BDCQ.SF1AA2CA  2022.06    1684.422        NaN      F  Dollars
# 25      BDCQ.SF1AA2CA  2022.09    1665.926        NaN      F  Dollars
# 26      BDCQ.SF1AA2CS  2016.06    1061.349        NaN      R  Dollars
# 27      BDCQ.SF1AA2CS  2016.09    1056.741        NaN      R  Dollars
# 28      BDCQ.SF1AA2CS  2016.12    1054.816        NaN      R  Dollars
# 29      BDCQ.SF1AA2CS  2017.03    1080.596        NaN      R  Dollars
# 30      BDCQ.SF1AA2CS  2017.06    1174.210        NaN      R  Dollars
# 31      BDCQ.SF1AA2CS  2017.09    1264.472        NaN      R  Dollars
# 32      BDCQ.SF1AA2CS  2017.12    1288.660        NaN      R  Dollars
# 33      BDCQ.SF1AA2CS  2018.03    1514.451        NaN      R  Dollars
# 34      BDCQ.SF1AA2CS  2018.06    1416.766        NaN      R  Dollars
# 35      BDCQ.SF1AA2CS  2018.09    1471.963        NaN      R  Dollars
# 36      BDCQ.SF1AA2CS  2018.12    1569.634        NaN      R  Dollars
# 37      BDCQ.SF1AA2CS  2019.03    1499.216        NaN      R  Dollars
# 38      BDCQ.SF1AA2CS  2019.06    1441.494        NaN      R  Dollars
# 39      BDCQ.SF1AA2CS  2019.09    1356.635        NaN      R  Dollars
# 40      BDCQ.SF1AA2CS  2019.12    1371.398        NaN      R  Dollars
# 41      BDCQ.SF1AA2CS  2020.03    1155.140        NaN      R  Dollars
# 42      BDCQ.SF1AA2CS  2020.06    1075.058        NaN      R  Dollars
# 43      BDCQ.SF1AA2CS  2020.09    1412.056        NaN      R  Dollars
# 44      BDCQ.SF1AA2CS  2020.12    1492.639        NaN      R  Dollars
# 45      BDCQ.SF1AA2CS  2021.03    1494.996        NaN      R  Dollars
# 46      BDCQ.SF1AA2CS  2021.06    1738.142        NaN      R  Dollars
# 47      BDCQ.SF1AA2CS  2021.09    1675.830        NaN      R  Dollars
# 48      BDCQ.SF1AA2CS  2021.12    1562.103        NaN      R  Dollars
# 49      BDCQ.SF1AA2CS  2022.03    1380.555        NaN      R  Dollars
# 50      BDCQ.SF1AA2CS  2022.06    1604.687        NaN      R  Dollars
# 51      BDCQ.SF1AA2CS  2022.09    1630.307        NaN      F  Dollars
# 52      BDCQ.SF1AA2CT  2016.06    1025.652        NaN      R  Dollars
# 53      BDCQ.SF1AA2CT  2016.09    1068.032        NaN      R  Dollars
# 54      BDCQ.SF1AA2CT  2016.12    1053.707        NaN      R  Dollars
# 55      BDCQ.SF1AA2CT  2017.03    1088.770        NaN      R  Dollars
# 56      BDCQ.SF1AA2CT  2017.06    1171.551        NaN      R  Dollars
# 57      BDCQ.SF1AA2CT  2017.09    1255.568        NaN      R  Dollars
# 58      BDCQ.SF1AA2CT  2017.12    1333.570        NaN      R  Dollars
# 59      BDCQ.SF1AA2CT  2018.03    1394.167        NaN      R  Dollars
# 60      BDCQ.SF1AA2CT  2018.06    1428.989        NaN      R  Dollars
# 61      BDCQ.SF1AA2CT  2018.09    1486.523        NaN      R  Dollars
# 62      BDCQ.SF1AA2CT  2018.12    1540.899        NaN      R  Dollars
# 63      BDCQ.SF1AA2CT  2019.03    1515.415        NaN      R  Dollars
# 64      BDCQ.SF1AA2CT  2019.06    1429.262        NaN      R  Dollars
# 65      BDCQ.SF1AA2CT  2019.09    1371.473        NaN      R  Dollars
# 66      BDCQ.SF1AA2CT  2019.12    1370.557        NaN      R  Dollars
# 67      BDCQ.SF1AA2CT  2020.03         NaN        NaN      C  Dollars
# 68      BDCQ.SF1AA2CT  2020.06         NaN        NaN      C  Dollars
# 69      BDCQ.SF1AA2CT  2020.09         NaN        NaN      C  Dollars
# 70      BDCQ.SF1AA2CT  2020.12         NaN        NaN      C  Dollars
# 71      BDCQ.SF1AA2CT  2021.03         NaN        NaN      C  Dollars
# 72      BDCQ.SF1AA2CT  2021.06         NaN        NaN      C  Dollars
# 73      BDCQ.SF1AA2CT  2021.09         NaN        NaN      C  Dollars
# 74      BDCQ.SF1AA2CT  2021.12         NaN        NaN      C  Dollars
# 75      BDCQ.SF1AA2CT  2022.03         NaN        NaN      C  Dollars
# 76      BDCQ.SF1AA2CT  2022.06         NaN        NaN      C  Dollars
# 77      BDCQ.SF1AA2CT  2022.09         NaN        NaN      C  Dollars
# 78      BDCQ.SF1AA3CA  2016.06    1189.735        NaN      F  Dollars
# 79      BDCQ.SF1AA3CA  2016.09    1144.938        NaN      F  Dollars
# 80      BDCQ.SF1AA3CA  2016.12    1390.589        NaN      F  Dollars
# 81      BDCQ.SF1AA3CA  2017.03    1310.912        NaN      F  Dollars
# 82      BDCQ.SF1AA3CA  2017.06    1241.466        NaN      F  Dollars
# 83      BDCQ.SF1AA3CA  2017.09    1288.648        NaN      F  Dollars
# 84      BDCQ.SF1AA3CA  2017.12    1772.086        NaN      F  Dollars
# 85      BDCQ.SF1AA3CA  2018.03    1554.221        NaN      F  Dollars
# 86      BDCQ.SF1AA3CA  2018.06    1441.386        NaN      F  Dollars
# 87      BDCQ.SF1AA3CA  2018.09    1364.769        NaN      F  Dollars
# 88      BDCQ.SF1AA3CA  2018.12    1771.028        NaN      F  Dollars
# 89      BDCQ.SF1AA3CA  2019.03    1665.840        NaN      F  Dollars
# 90      BDCQ.SF1AA3CA  2019.06    1554.397        NaN      F  Dollars
# 91      BDCQ.SF1AA3CA  2019.09    1484.434        NaN      F  Dollars
# 92      BDCQ.SF1AA3CA  2019.12    1817.118        NaN      F  Dollars
# 93      BDCQ.SF1AA3CA  2020.03    1582.915        NaN      F  Dollars
# 94      BDCQ.SF1AA3CA  2020.06    1421.593        NaN      F  Dollars
# 95      BDCQ.SF1AA3CA  2020.09    1614.752        NaN      F  Dollars
# 96      BDCQ.SF1AA3CA  2020.12    2089.453        NaN      F  Dollars
# 97      BDCQ.SF1AA3CA  2021.03    1817.439        NaN      F  Dollars
# 98      BDCQ.SF1AA3CA  2021.06    1814.973        NaN      F  Dollars
# 99      BDCQ.SF1AA3CA  2021.09    1791.805        NaN      F  Dollars
# 100     BDCQ.SF1AA3CA  2021.12    2325.251        NaN      F  Dollars
# 101     BDCQ.SF1AA3CA  2022.03    2001.763        NaN      F  Dollars
# 102     BDCQ.SF1AA3CA  2022.06    1861.241        NaN      F  Dollars
# 103     BDCQ.SF1AA3CA  2022.09    1755.338        NaN      F  Dollars
# 104     BDCQ.SF1AA3CS  2016.06    1266.373        NaN      R  Dollars
# 105     BDCQ.SF1AA3CS  2016.09    1289.899        NaN      R  Dollars
# 106     BDCQ.SF1AA3CS  2016.12    1221.303        NaN      R  Dollars
# 107     BDCQ.SF1AA3CS  2017.03    1266.987        NaN      R  Dollars
# 108     BDCQ.SF1AA3CS  2017.06    1329.091        NaN      R  Dollars
# 109     BDCQ.SF1AA3CS  2017.09    1440.993        NaN      R  Dollars
# 110     BDCQ.SF1AA3CS  2017.12    1550.720        NaN      R  Dollars
# 111     BDCQ.SF1AA3CS  2018.03    1515.056        NaN      R  Dollars
# 112     BDCQ.SF1AA3CS  2018.06    1543.911        NaN      R  Dollars
# 113     BDCQ.SF1AA3CS  2018.09    1518.513        NaN      R  Dollars
# 114     BDCQ.SF1AA3CS  2018.12    1541.299        NaN      R  Dollars
# 115     BDCQ.SF1AA3CS  2019.03    1642.343        NaN      R  Dollars
# 116     BDCQ.SF1AA3CS  2019.06    1662.180        NaN      R  Dollars
# 117     BDCQ.SF1AA3CS  2019.09    1643.284        NaN      R  Dollars
# 118     BDCQ.SF1AA3CS  2019.12    1577.224        NaN      R  Dollars
# 119     BDCQ.SF1AA3CS  2020.03    1573.532        NaN      R  Dollars
# 120     BDCQ.SF1AA3CS  2020.06    1517.125        NaN      R  Dollars
# 121     BDCQ.SF1AA3CS  2020.09    1782.909        NaN      R  Dollars
# 122     BDCQ.SF1AA3CS  2020.12    1809.248        NaN      R  Dollars
# 123     BDCQ.SF1AA3CS  2021.03    1816.554        NaN      R  Dollars
# 124     BDCQ.SF1AA3CS  2021.06    1935.556        NaN      R  Dollars
# 125     BDCQ.SF1AA3CS  2021.09    1973.420        NaN      R  Dollars
# 126     BDCQ.SF1AA3CS  2021.12    2013.062        NaN      R  Dollars
# 127     BDCQ.SF1AA3CS  2022.03    2004.615        NaN      R  Dollars
# 128     BDCQ.SF1AA3CS  2022.06    1984.624        NaN      R  Dollars
# 129     BDCQ.SF1AA3CS  2022.09    1931.071        NaN      F  Dollars
# 130     BDCQ.SF1AA3CT  2016.06    1283.518        NaN      R  Dollars
# 131     BDCQ.SF1AA3CT  2016.09    1264.812        NaN      R  Dollars
# 132     BDCQ.SF1AA3CT  2016.12    1243.644        NaN      R  Dollars
# 133     BDCQ.SF1AA3CT  2017.03    1257.350        NaN      R  Dollars
# 134     BDCQ.SF1AA3CT  2017.06    1335.358        NaN      R  Dollars
# 135     BDCQ.SF1AA3CT  2017.09    1447.693        NaN      R  Dollars
# 136     BDCQ.SF1AA3CT  2017.12    1524.791        NaN      R  Dollars
# 137     BDCQ.SF1AA3CT  2018.03    1539.190        NaN      R  Dollars
# 138     BDCQ.SF1AA3CT  2018.06    1527.668        NaN      R  Dollars
# 139     BDCQ.SF1AA3CT  2018.09    1523.826        NaN      R  Dollars
# 140     BDCQ.SF1AA3CT  2018.12    1555.216        NaN      R  Dollars
# 141     BDCQ.SF1AA3CT  2019.03    1627.515        NaN      R  Dollars
# 142     BDCQ.SF1AA3CT  2019.06    1665.918        NaN      R  Dollars
# 143     BDCQ.SF1AA3CT  2019.09    1634.622        NaN      R  Dollars
# 144     BDCQ.SF1AA3CT  2019.12    1587.142        NaN      R  Dollars
# 145     BDCQ.SF1AA3CT  2020.03         NaN        NaN      C  Dollars
# 146     BDCQ.SF1AA3CT  2020.06         NaN        NaN      C  Dollars
# 147     BDCQ.SF1AA3CT  2020.09         NaN        NaN      C  Dollars
# 148     BDCQ.SF1AA3CT  2020.12         NaN        NaN      C  Dollars
# 149     BDCQ.SF1AA3CT  2021.03         NaN        NaN      C  Dollars
# 150     BDCQ.SF1AA3CT  2021.06         NaN        NaN      C  Dollars
# 151     BDCQ.SF1AA3CT  2021.09         NaN        NaN      C  Dollars
# 152     BDCQ.SF1AA3CT  2021.12         NaN        NaN      C  Dollars
# 153     BDCQ.SF1AA3CT  2022.03         NaN        NaN      C  Dollars
# 154     BDCQ.SF1AA3CT  2022.06         NaN        NaN      C  Dollars
# 155     BDCQ.SF1AA3CT  2022.09         NaN        NaN      C  Dollars
# 156      BDCQ.SF1AACA  2016.06    2306.120        NaN      F  Dollars
# 157      BDCQ.SF1AACA  2016.09    2215.810        NaN      F  Dollars
# 158      BDCQ.SF1AACA  2016.12    2445.000        NaN      F  Dollars
# 159      BDCQ.SF1AACA  2017.03    2321.580        NaN      F  Dollars
# 160      BDCQ.SF1AACA  2017.06    2475.220        NaN      F  Dollars
# 161      BDCQ.SF1AACA  2017.09    2571.090        NaN      F  Dollars
# 162      BDCQ.SF1AACA  2017.12    3062.910        NaN      F  Dollars
# 163      BDCQ.SF1AACA  2018.03    2966.240        NaN      F  Dollars
# 164      BDCQ.SF1AACA  2018.06    2929.480        NaN      F  Dollars
# 165      BDCQ.SF1AACA  2018.09    2862.450        NaN      F  Dollars
# 166      BDCQ.SF1AACA  2018.12    3341.530        NaN      F  Dollars
# 167      BDCQ.SF1AACA  2019.03    3059.590        NaN      F  Dollars
# 168      BDCQ.SF1AACA  2019.06    3071.570        NaN      F  Dollars
# 169      BDCQ.SF1AACA  2019.09    2865.950        NaN      F  Dollars
# 170      BDCQ.SF1AACA  2019.12    3188.100        NaN      F  Dollars
# 171      BDCQ.SF1AACA  2020.03    2655.930        NaN      F  Dollars
# 172      BDCQ.SF1AACA  2020.06    2553.038        NaN      F  Dollars
# 173      BDCQ.SF1AACA  2020.09    3054.853        NaN      F  Dollars
# 174      BDCQ.SF1AACA  2020.12    3579.432        NaN      F  Dollars
# 175      BDCQ.SF1AACA  2021.03    3208.221        NaN      F  Dollars
# 176      BDCQ.SF1AACA  2021.06    3641.703        NaN      F  Dollars
# 177      BDCQ.SF1AACA  2021.09    3501.878        NaN      F  Dollars
# 178      BDCQ.SF1AACA  2021.12    3884.730        NaN      F  Dollars
# 179      BDCQ.SF1AACA  2022.03    3286.846        NaN      F  Dollars
# 180      BDCQ.SF1AACA  2022.06    3545.663        NaN      F  Dollars
# 181      BDCQ.SF1AACA  2022.09    3421.264        NaN      F  Dollars
# 182      BDCQ.SF1AACS  2016.06    2332.263        NaN      R  Dollars
# 183      BDCQ.SF1AACS  2016.09    2349.284        NaN      R  Dollars
# 184      BDCQ.SF1AACS  2016.12    2278.398        NaN      R  Dollars
# 185      BDCQ.SF1AACS  2017.03    2336.167        NaN      R  Dollars
# 186      BDCQ.SF1AACS  2017.06    2503.212        NaN      R  Dollars
# 187      BDCQ.SF1AACS  2017.09    2717.968        NaN      R  Dollars
# 188      BDCQ.SF1AACS  2017.12    2854.459        NaN      R  Dollars
# 189      BDCQ.SF1AACS  2018.03    2997.028        NaN      R  Dollars
# 190      BDCQ.SF1AACS  2018.06    2957.251        NaN      R  Dollars
# 191      BDCQ.SF1AACS  2018.09    3017.438        NaN      R  Dollars
# 192      BDCQ.SF1AACS  2018.12    3117.474        NaN      R  Dollars
# 193      BDCQ.SF1AACS  2019.03    3099.604        NaN      R  Dollars
# 194      BDCQ.SF1AACS  2019.06    3096.801        NaN      R  Dollars
# 195      BDCQ.SF1AACS  2019.09    3015.344        NaN      R  Dollars
# 196      BDCQ.SF1AACS  2019.12    2974.886        NaN      R  Dollars
# 197      BDCQ.SF1AACS  2020.03    2697.931        NaN      R  Dollars
# 198      BDCQ.SF1AACS  2020.06    2570.945        NaN      R  Dollars
# 199      BDCQ.SF1AACS  2020.09    3209.321        NaN      R  Dollars
# 200      BDCQ.SF1AACS  2020.12    3340.608        NaN      R  Dollars
# 201      BDCQ.SF1AACS  2021.03    3266.448        NaN      R  Dollars
# 202      BDCQ.SF1AACS  2021.06    3662.679        NaN      R  Dollars
# 203      BDCQ.SF1AACS  2021.09    3674.977        NaN      R  Dollars
# 204      BDCQ.SF1AACS  2021.12    3625.819        NaN      R  Dollars
# 205      BDCQ.SF1AACS  2022.03    3353.077        NaN      R  Dollars
# 206      BDCQ.SF1AACS  2022.06    3563.277        NaN      R  Dollars
# 207      BDCQ.SF1AACS  2022.09    3585.729        NaN      F  Dollars
# 208      BDCQ.SF1AACT  2016.06    2312.196        NaN      R  Dollars
# 209      BDCQ.SF1AACT  2016.09    2337.005        NaN      R  Dollars
# 210      BDCQ.SF1AACT  2016.12    2295.722        NaN      R  Dollars
# 211      BDCQ.SF1AACT  2017.03    2339.265        NaN      R  Dollars
# 212      BDCQ.SF1AACT  2017.06    2507.941        NaN      R  Dollars
# 213      BDCQ.SF1AACT  2017.09    2702.525        NaN      R  Dollars
# 214      BDCQ.SF1AACT  2017.12    2874.487        NaN      R  Dollars
# 215      BDCQ.SF1AACT  2018.03    2962.464        NaN      R  Dollars
# 216      BDCQ.SF1AACT  2018.06    2982.394        NaN      R  Dollars
# 217      BDCQ.SF1AACT  2018.09    3024.607        NaN      R  Dollars
# 218      BDCQ.SF1AACT  2018.12    3096.127        NaN      R  Dollars
# 219      BDCQ.SF1AACT  2019.03    3116.250        NaN      R  Dollars
# 220      BDCQ.SF1AACT  2019.06    3081.134        NaN      R  Dollars
# 221      BDCQ.SF1AACT  2019.09    3019.296        NaN      R  Dollars
# 222      BDCQ.SF1AACT  2019.12    2985.529        NaN      R  Dollars
# 223      BDCQ.SF1AACT  2020.03         NaN        NaN      C  Dollars
# 224      BDCQ.SF1AACT  2020.06         NaN        NaN      C  Dollars
# 225      BDCQ.SF1AACT  2020.09         NaN        NaN      C  Dollars
# 226      BDCQ.SF1AACT  2020.12         NaN        NaN      C  Dollars
# 227      BDCQ.SF1AACT  2021.03         NaN        NaN      C  Dollars
# 228      BDCQ.SF1AACT  2021.06         NaN        NaN      C  Dollars
# 229      BDCQ.SF1AACT  2021.09         NaN        NaN      C  Dollars
# 230      BDCQ.SF1AACT  2021.12         NaN        NaN      C  Dollars
# 231      BDCQ.SF1AACT  2022.03         NaN        NaN      C  Dollars
# 232      BDCQ.SF1AACT  2022.06         NaN        NaN      C  Dollars
# 233      BDCQ.SF1AACT  2022.09         NaN        NaN      C  Dollars
# 234     BDCQ.SF1BB1CA  2016.06    1119.020        NaN      F  Dollars
# 235     BDCQ.SF1BB1CA  2016.09    1101.412        NaN      F  Dollars
# 236     BDCQ.SF1BB1CA  2016.12    1139.459        NaN      F  Dollars
# 237     BDCQ.SF1BB1CA  2017.03    1040.500        NaN      F  Dollars
# 238     BDCQ.SF1BB1CA  2017.06    1150.976        NaN      F  Dollars
# 239     BDCQ.SF1BB1CA  2017.09    1084.658        NaN      F  Dollars
# 240     BDCQ.SF1BB1CA  2017.12    1352.840        NaN      F  Dollars
# 241     BDCQ.SF1BB1CA  2018.03    1224.534        NaN      F  Dollars
# 242     BDCQ.SF1BB1CA  2018.06    1105.167        NaN      F  Dollars
# 243     BDCQ.SF1BB1CA  2018.09    1372.723        NaN      F  Dollars
# 244     BDCQ.SF1BB1CA  2018.12    1230.969        NaN      F  Dollars
# 245     BDCQ.SF1BB1CA  2019.03    1115.478        NaN      F  Dollars
# 246     BDCQ.SF1BB1CA  2019.06    1210.962        NaN      F  Dollars
# 247     BDCQ.SF1BB1CA  2019.09    1234.819        NaN      F  Dollars
# 248     BDCQ.SF1BB1CA  2019.12    1276.337        NaN      F  Dollars
# 249     BDCQ.SF1BB1CA  2020.03    1080.713        NaN      F  Dollars
# 250     BDCQ.SF1BB1CA  2020.06     847.349        NaN      F  Dollars
# 251     BDCQ.SF1BB1CA  2020.09     925.547        NaN      F  Dollars
# 252     BDCQ.SF1BB1CA  2020.12    1085.539        NaN      F  Dollars
# 253     BDCQ.SF1BB1CA  2021.03    1063.775        NaN      F  Dollars
# 254     BDCQ.SF1BB1CA  2021.06    1077.447        NaN      F  Dollars
# 255     BDCQ.SF1BB1CA  2021.09    1151.861        NaN      F  Dollars
# 256     BDCQ.SF1BB1CA  2021.12    1202.160        NaN      F  Dollars
# 257     BDCQ.SF1BB1CA  2022.03    1244.801        NaN      F  Dollars
# 258     BDCQ.SF1BB1CA  2022.06    1448.299        NaN      F  Dollars
# 259     BDCQ.SF1BB1CA  2022.09    1441.298        NaN      F  Dollars
# 260     BDCQ.SF1BB1CS  2016.06    1119.020        NaN      R  Dollars
# 261     BDCQ.SF1BB1CS  2016.09    1101.412        NaN      R  Dollars
# 262     BDCQ.SF1BB1CS  2016.12    1139.459        NaN      R  Dollars
# 263     BDCQ.SF1BB1CS  2017.03    1040.500        NaN      R  Dollars
# 264     BDCQ.SF1BB1CS  2017.06    1150.976        NaN      R  Dollars
# 265     BDCQ.SF1BB1CS  2017.09    1084.658        NaN      R  Dollars
# 266     BDCQ.SF1BB1CS  2017.12    1352.840        NaN      R  Dollars
# 267     BDCQ.SF1BB1CS  2018.03    1224.534        NaN      R  Dollars
# 268     BDCQ.SF1BB1CS  2018.06    1105.167        NaN      R  Dollars
# 269     BDCQ.SF1BB1CS  2018.09    1372.723        NaN      R  Dollars
# 270     BDCQ.SF1BB1CS  2018.12    1230.969        NaN      R  Dollars
# 271     BDCQ.SF1BB1CS  2019.03    1115.478        NaN      R  Dollars
# 272     BDCQ.SF1BB1CS  2019.06    1210.962        NaN      R  Dollars
# 273     BDCQ.SF1BB1CS  2019.09    1234.819        NaN      R  Dollars
# 274     BDCQ.SF1BB1CS  2019.12    1276.337        NaN      R  Dollars
# 275     BDCQ.SF1BB1CS  2020.03    1080.713        NaN      R  Dollars
# 276     BDCQ.SF1BB1CS  2020.06     847.349        NaN      R  Dollars
# 277     BDCQ.SF1BB1CS  2020.09     925.547        NaN      R  Dollars
# 278     BDCQ.SF1BB1CS  2020.12    1085.539        NaN      R  Dollars
# 279     BDCQ.SF1BB1CS  2021.03    1063.775        NaN      R  Dollars
# 280     BDCQ.SF1BB1CS  2021.06    1077.447        NaN      R  Dollars
# 281     BDCQ.SF1BB1CS  2021.09    1151.861        NaN      R  Dollars
# 282     BDCQ.SF1BB1CS  2021.12    1202.160        NaN      R  Dollars
# 283     BDCQ.SF1BB1CS  2022.03    1244.801        NaN      R  Dollars
# 284     BDCQ.SF1BB1CS  2022.06    1448.299        NaN      R  Dollars
# 285     BDCQ.SF1BB1CS  2022.09    1441.298        NaN      F  Dollars
# 286     BDCQ.SF1BB1CT  2016.06    1116.391        NaN      R  Dollars
# 287     BDCQ.SF1BB1CT  2016.09    1117.962        NaN      R  Dollars
# 288     BDCQ.SF1BB1CT  2016.12    1099.874        NaN      R  Dollars
# 289     BDCQ.SF1BB1CT  2017.03    1094.298        NaN      R  Dollars
# 290     BDCQ.SF1BB1CT  2017.06    1085.074        NaN      R  Dollars
# 291     BDCQ.SF1BB1CT  2017.09    1175.875        NaN      R  Dollars
# 292     BDCQ.SF1BB1CT  2017.12    1264.632        NaN      R  Dollars
# 293     BDCQ.SF1BB1CT  2018.03    1251.321        NaN      R  Dollars
# 294     BDCQ.SF1BB1CT  2018.06    1204.844        NaN      R  Dollars
# 295     BDCQ.SF1BB1CT  2018.09    1257.817        NaN      R  Dollars
# 296     BDCQ.SF1BB1CT  2018.12    1221.776        NaN      R  Dollars
# 297     BDCQ.SF1BB1CT  2019.03    1155.503        NaN      R  Dollars
# 298     BDCQ.SF1BB1CT  2019.06    1183.655        NaN      R  Dollars
# 299     BDCQ.SF1BB1CT  2019.09    1260.084        NaN      R  Dollars
# 300     BDCQ.SF1BB1CT  2019.12    1242.986        NaN      R  Dollars
# 301     BDCQ.SF1BB1CT  2020.03         NaN        NaN      C  Dollars
# 302     BDCQ.SF1BB1CT  2020.06         NaN        NaN      C  Dollars
# 303     BDCQ.SF1BB1CT  2020.09         NaN        NaN      C  Dollars
# 304     BDCQ.SF1BB1CT  2020.12         NaN        NaN      C  Dollars
# 305     BDCQ.SF1BB1CT  2021.03         NaN        NaN      C  Dollars
# 306     BDCQ.SF1BB1CT  2021.06         NaN        NaN      C  Dollars
# 307     BDCQ.SF1BB1CT  2021.09         NaN        NaN      C  Dollars
# 308     BDCQ.SF1BB1CT  2021.12         NaN        NaN      C  Dollars
# 309     BDCQ.SF1BB1CT  2022.03         NaN        NaN      C  Dollars
# 310     BDCQ.SF1BB1CT  2022.06         NaN        NaN      C  Dollars
# 311     BDCQ.SF1BB1CT  2022.09         NaN        NaN      C  Dollars
# 312      BDCQ.SF1BBCA  2016.06    1119.020        NaN      F  Dollars
# 313      BDCQ.SF1BBCA  2016.09    1101.412        NaN      F  Dollars
# 314      BDCQ.SF1BBCA  2016.12    1139.459        NaN      F  Dollars
# 315      BDCQ.SF1BBCA  2017.03    1040.500        NaN      F  Dollars
# 316      BDCQ.SF1BBCA  2017.06    1150.976        NaN      F  Dollars
# 317      BDCQ.SF1BBCA  2017.09    1084.658        NaN      F  Dollars
# 318      BDCQ.SF1BBCA  2017.12    1352.840        NaN      F  Dollars
# 319      BDCQ.SF1BBCA  2018.03    1224.534        NaN      F  Dollars
# 320      BDCQ.SF1BBCA  2018.06    1105.167        NaN      F  Dollars
# 321      BDCQ.SF1BBCA  2018.09    1372.723        NaN      F  Dollars
# 322      BDCQ.SF1BBCA  2018.12    1230.969        NaN      F  Dollars
# 323      BDCQ.SF1BBCA  2019.03    1115.478        NaN      F  Dollars
# 324      BDCQ.SF1BBCA  2019.06    1210.962        NaN      F  Dollars
# 325      BDCQ.SF1BBCA  2019.09    1234.819        NaN      F  Dollars
# 326      BDCQ.SF1BBCA  2019.12    1276.337        NaN      F  Dollars
# 327      BDCQ.SF1BBCA  2020.03    1080.713        NaN      F  Dollars
# 328      BDCQ.SF1BBCA  2020.06     847.349        NaN      F  Dollars
# 329      BDCQ.SF1BBCA  2020.09     925.547        NaN      F  Dollars
# 330      BDCQ.SF1BBCA  2020.12    1085.539        NaN      F  Dollars
# 331      BDCQ.SF1BBCA  2021.03    1063.775        NaN      F  Dollars
# 332      BDCQ.SF1BBCA  2021.06    1077.447        NaN      F  Dollars
# 333      BDCQ.SF1BBCA  2021.09    1151.861        NaN      F  Dollars
# 334      BDCQ.SF1BBCA  2021.12    1202.160        NaN      F  Dollars
# 335      BDCQ.SF1BBCA  2022.03    1244.801        NaN      F  Dollars
# 336      BDCQ.SF1BBCA  2022.06    1448.299        NaN      F  Dollars
# 337      BDCQ.SF1BBCA  2022.09    1441.298        NaN      F  Dollars
# 338      BDCQ.SF1BBCS  2016.06    1119.020        NaN      R  Dollars
# 339      BDCQ.SF1BBCS  2016.09    1101.412        NaN      R  Dollars
# 340      BDCQ.SF1BBCS  2016.12    1139.459        NaN      R  Dollars
# 341      BDCQ.SF1BBCS  2017.03    1040.500        NaN      R  Dollars
# 342      BDCQ.SF1BBCS  2017.06    1150.976        NaN      R  Dollars
# 343      BDCQ.SF1BBCS  2017.09    1084.658        NaN      R  Dollars
# 344      BDCQ.SF1BBCS  2017.12    1352.840        NaN      R  Dollars
# 345      BDCQ.SF1BBCS  2018.03    1224.534        NaN      R  Dollars
# 346      BDCQ.SF1BBCS  2018.06    1105.167        NaN      R  Dollars
# 347      BDCQ.SF1BBCS  2018.09    1372.723        NaN      R  Dollars
# 348      BDCQ.SF1BBCS  2018.12    1230.969        NaN      R  Dollars
# 349      BDCQ.SF1BBCS  2019.03    1115.478        NaN      R  Dollars
# 350      BDCQ.SF1BBCS  2019.06    1210.962        NaN      R  Dollars
# 351      BDCQ.SF1BBCS  2019.09    1234.819        NaN      R  Dollars
# 352      BDCQ.SF1BBCS  2019.12    1276.337        NaN      R  Dollars
# 353      BDCQ.SF1BBCS  2020.03    1080.713        NaN      R  Dollars
# 354      BDCQ.SF1BBCS  2020.06     847.349        NaN      R  Dollars
# 355      BDCQ.SF1BBCS  2020.09     925.547        NaN      R  Dollars
# 356      BDCQ.SF1BBCS  2020.12    1085.539        NaN      R  Dollars
# 357      BDCQ.SF1BBCS  2021.03    1063.775        NaN      R  Dollars
# 358      BDCQ.SF1BBCS  2021.06    1077.447        NaN      R  Dollars
# 359      BDCQ.SF1BBCS  2021.09    1151.861        NaN      R  Dollars
# 360      BDCQ.SF1BBCS  2021.12    1202.160        NaN      R  Dollars
# 361      BDCQ.SF1BBCS  2022.03    1244.801        NaN      R  Dollars
# 362      BDCQ.SF1BBCS  2022.06    1448.299        NaN      R  Dollars
# 363      BDCQ.SF1BBCS  2022.09    1441.298        NaN      F  Dollars
# 364      BDCQ.SF1BBCT  2016.06    1116.391        NaN      R  Dollars
# 365      BDCQ.SF1BBCT  2016.09    1117.962        NaN      R  Dollars
# 366      BDCQ.SF1BBCT  2016.12    1099.874        NaN      R  Dollars
# 367      BDCQ.SF1BBCT  2017.03    1094.298        NaN      R  Dollars
# 368      BDCQ.SF1BBCT  2017.06    1085.074        NaN      R  Dollars
# 369      BDCQ.SF1BBCT  2017.09    1175.875        NaN      R  Dollars
# 370      BDCQ.SF1BBCT  2017.12    1264.632        NaN      R  Dollars
# 371      BDCQ.SF1BBCT  2018.03    1251.321        NaN      R  Dollars
# 372      BDCQ.SF1BBCT  2018.06    1204.844        NaN      R  Dollars
# 373      BDCQ.SF1BBCT  2018.09    1257.817        NaN      R  Dollars
# 374      BDCQ.SF1BBCT  2018.12    1221.776        NaN      R  Dollars
# 375      BDCQ.SF1BBCT  2019.03    1155.503        NaN      R  Dollars
# 376      BDCQ.SF1BBCT  2019.06    1183.655        NaN      R  Dollars
# 377      BDCQ.SF1BBCT  2019.09    1260.084        NaN      R  Dollars
# 378      BDCQ.SF1BBCT  2019.12    1242.986        NaN      R  Dollars
# 379      BDCQ.SF1BBCT  2020.03         NaN        NaN      C  Dollars
# 380      BDCQ.SF1BBCT  2020.06         NaN        NaN      C  Dollars
# 381      BDCQ.SF1BBCT  2020.09         NaN        NaN      C  Dollars
# 382      BDCQ.SF1BBCT  2020.12         NaN        NaN      C  Dollars
# 383      BDCQ.SF1BBCT  2021.03         NaN        NaN      C  Dollars
# 384      BDCQ.SF1BBCT  2021.06         NaN        NaN      C  Dollars
# 385      BDCQ.SF1BBCT  2021.09         NaN        NaN      C  Dollars
# 386      BDCQ.SF1BBCT  2021.12         NaN        NaN      C  Dollars
# 387      BDCQ.SF1BBCT  2022.03         NaN        NaN      C  Dollars
# 388      BDCQ.SF1BBCT  2022.06         NaN        NaN      C  Dollars
# 389      BDCQ.SF1BBCT  2022.09         NaN        NaN      C  Dollars
# 390     BDCQ.SF1CC1CA  2016.06   10624.465        NaN      F  Dollars
# 391     BDCQ.SF1CC1CA  2016.09    9110.709        NaN      F  Dollars
# 392     BDCQ.SF1CC1CA  2016.12   12084.429        NaN      F  Dollars
# 393     BDCQ.SF1CC1CA  2017.03   11804.216        NaN      F  Dollars
# 394     BDCQ.SF1CC1CA  2017.06   12150.005        NaN      F  Dollars
# 395     BDCQ.SF1CC1CA  2017.09   10399.584        NaN      F  Dollars
# 396     BDCQ.SF1CC1CA  2017.12   13705.071        NaN      F  Dollars
# 397     BDCQ.SF1CC1CA  2018.03   12745.412        NaN      F  Dollars
# 398     BDCQ.SF1CC1CA  2018.06   12574.246        NaN      F  Dollars
# 399     BDCQ.SF1CC1CA  2018.09   10633.605        NaN      F  Dollars
# 400     BDCQ.SF1CC1CA  2018.12   13806.468        NaN      F  Dollars
# 401     BDCQ.SF1CC1CA  2019.03   13704.407        NaN      F  Dollars
# 402     BDCQ.SF1CC1CA  2019.06   13035.873        NaN      F  Dollars
# 403     BDCQ.SF1CC1CA  2019.09   11170.665        NaN      F  Dollars
# 404     BDCQ.SF1CC1CA  2019.12   15202.125        NaN      F  Dollars
# 405     BDCQ.SF1CC1CA  2020.03   14554.796        NaN      F  Dollars
# 406     BDCQ.SF1CC1CA  2020.06   13611.426        NaN      F  Dollars
# 407     BDCQ.SF1CC1CA  2020.09   11354.265        NaN      F  Dollars
# 408     BDCQ.SF1CC1CA  2020.12   14450.272        NaN      F  Dollars
# 409     BDCQ.SF1CC1CA  2021.03   14066.305        NaN      F  Dollars
# 410     BDCQ.SF1CC1CA  2021.06   14238.983        NaN      F  Dollars
# 411     BDCQ.SF1CC1CA  2021.09   12297.488        NaN      F  Dollars
# 412     BDCQ.SF1CC1CA  2021.12   16382.914        NaN      F  Dollars
# 413     BDCQ.SF1CC1CA  2022.03   15717.522        NaN      F  Dollars
# 414     BDCQ.SF1CC1CA  2022.06   16272.442        NaN      F  Dollars
# 415     BDCQ.SF1CC1CA  2022.09   15435.099        NaN      F  Dollars
# 416     BDCQ.SF1CC1CS  2016.06   10645.533        NaN      R  Dollars
# 417     BDCQ.SF1CC1CS  2016.09   10746.161        NaN      R  Dollars
# 418     BDCQ.SF1CC1CS  2016.12   10993.057        NaN      R  Dollars
# 419     BDCQ.SF1CC1CS  2017.03   11227.630        NaN      R  Dollars
# 420     BDCQ.SF1CC1CS  2017.06   12124.058        NaN      R  Dollars
# 421     BDCQ.SF1CC1CS  2017.09   12257.443        NaN      R  Dollars
# 422     BDCQ.SF1CC1CS  2017.12   12472.544        NaN      R  Dollars
# 423     BDCQ.SF1CC1CS  2018.03   12159.422        NaN      R  Dollars
# 424     BDCQ.SF1CC1CS  2018.06   12505.921        NaN      R  Dollars
# 425     BDCQ.SF1CC1CS  2018.09   12545.318        NaN      R  Dollars
# 426     BDCQ.SF1CC1CS  2018.12   12552.711        NaN      R  Dollars
# 427     BDCQ.SF1CC1CS  2019.03   13105.416        NaN      R  Dollars
# 428     BDCQ.SF1CC1CS  2019.06   12946.436        NaN      R  Dollars
# 429     BDCQ.SF1CC1CS  2019.09   13172.572        NaN      R  Dollars
# 430     BDCQ.SF1CC1CS  2019.12   13827.797        NaN      R  Dollars
# 431     BDCQ.SF1CC1CS  2020.03   13918.038        NaN      R  Dollars
# 432     BDCQ.SF1CC1CS  2020.06   13528.832        NaN      R  Dollars
# 433     BDCQ.SF1CC1CS  2020.09   13371.957        NaN      R  Dollars
# 434     BDCQ.SF1CC1CS  2020.12   13143.272        NaN      R  Dollars
# 435     BDCQ.SF1CC1CS  2021.03   13450.433        NaN      R  Dollars
# 436     BDCQ.SF1CC1CS  2021.06   14177.915        NaN      R  Dollars
# 437     BDCQ.SF1CC1CS  2021.09   14450.361        NaN      R  Dollars
# 438     BDCQ.SF1CC1CS  2021.12   14904.905        NaN      R  Dollars
# 439     BDCQ.SF1CC1CS  2022.03   15032.857        NaN      R  Dollars
# 440     BDCQ.SF1CC1CS  2022.06   16209.134        NaN      R  Dollars
# 441     BDCQ.SF1CC1CS  2022.09   18120.489        NaN      F  Dollars
# 442     BDCQ.SF1CC1CT  2016.06   10658.370        NaN      R  Dollars
# 443     BDCQ.SF1CC1CT  2016.09   10755.601        NaN      R  Dollars
# 444     BDCQ.SF1CC1CT  2016.12   10931.910        NaN      R  Dollars
# 445     BDCQ.SF1CC1CT  2017.03   11381.758        NaN      R  Dollars
# 446     BDCQ.SF1CC1CT  2017.06   11957.405        NaN      R  Dollars
# 447     BDCQ.SF1CC1CT  2017.09   12364.256        NaN      R  Dollars
# 448     BDCQ.SF1CC1CT  2017.12   12340.539        NaN      R  Dollars
# 449     BDCQ.SF1CC1CT  2018.03   12317.624        NaN      R  Dollars
# 450     BDCQ.SF1CC1CT  2018.06   12414.738        NaN      R  Dollars
# 451     BDCQ.SF1CC1CT  2018.09   12523.127        NaN      R  Dollars
# 452     BDCQ.SF1CC1CT  2018.12   12687.398        NaN      R  Dollars
# 453     BDCQ.SF1CC1CT  2019.03   12932.585        NaN      R  Dollars
# 454     BDCQ.SF1CC1CT  2019.06   13023.742        NaN      R  Dollars
# 455     BDCQ.SF1CC1CT  2019.09   13248.792        NaN      R  Dollars
# 456     BDCQ.SF1CC1CT  2019.12   13748.525        NaN      R  Dollars
# 457     BDCQ.SF1CC1CT  2020.03         NaN        NaN      C  Dollars
# 458     BDCQ.SF1CC1CT  2020.06         NaN        NaN      C  Dollars
# 459     BDCQ.SF1CC1CT  2020.09         NaN        NaN      C  Dollars
# 460     BDCQ.SF1CC1CT  2020.12         NaN        NaN      C  Dollars
# 461     BDCQ.SF1CC1CT  2021.03         NaN        NaN      C  Dollars
# 462     BDCQ.SF1CC1CT  2021.06         NaN        NaN      C  Dollars
# 463     BDCQ.SF1CC1CT  2021.09         NaN        NaN      C  Dollars
# 464     BDCQ.SF1CC1CT  2021.12         NaN        NaN      C  Dollars
# 465     BDCQ.SF1CC1CT  2022.03         NaN        NaN      C  Dollars
# 466     BDCQ.SF1CC1CT  2022.06         NaN        NaN      C  Dollars
# 467     BDCQ.SF1CC1CT  2022.09         NaN        NaN      C  Dollars
# 468     BDCQ.SF1CC2CA  2016.06     586.399        NaN      F  Dollars
# 469     BDCQ.SF1CC2CA  2016.09     577.941        NaN      F  Dollars
# 470     BDCQ.SF1CC2CA  2016.12     571.523        NaN      F  Dollars
# 471     BDCQ.SF1CC2CA  2017.03     572.279        NaN      F  Dollars
# 472     BDCQ.SF1CC2CA  2017.06     553.194        NaN      F  Dollars
# 473     BDCQ.SF1CC2CA  2017.09     541.030        NaN      F  Dollars
# 474     BDCQ.SF1CC2CA  2017.12     592.754        NaN      F  Dollars
# 475     BDCQ.SF1CC2CA  2018.03     530.018        NaN      F  Dollars
# 476     BDCQ.SF1CC2CA  2018.06     556.048        NaN      F  Dollars
# 477     BDCQ.SF1CC2CA  2018.09     541.341        NaN      F  Dollars
# 478     BDCQ.SF1CC2CA  2018.12     565.895        NaN      F  Dollars
# 479     BDCQ.SF1CC2CA  2019.03     527.250        NaN      F  Dollars
# 480     BDCQ.SF1CC2CA  2019.06     549.739        NaN      F  Dollars
# 481     BDCQ.SF1CC2CA  2019.09     524.132        NaN      F  Dollars
# 482     BDCQ.SF1CC2CA  2019.12     516.651        NaN      F  Dollars
# 483     BDCQ.SF1CC2CA  2020.03     444.847        NaN      F  Dollars
# 484     BDCQ.SF1CC2CA  2020.06     348.318        NaN      F  Dollars
# 485     BDCQ.SF1CC2CA  2020.09     503.119        NaN      F  Dollars
# 486     BDCQ.SF1CC2CA  2020.12     475.924        NaN      F  Dollars
# 487     BDCQ.SF1CC2CA  2021.03     468.887        NaN      F  Dollars
# 488     BDCQ.SF1CC2CA  2021.06     490.221        NaN      F  Dollars
# 489     BDCQ.SF1CC2CA  2021.09     451.072        NaN      F  Dollars
# 490     BDCQ.SF1CC2CA  2021.12     529.063        NaN      F  Dollars
# 491     BDCQ.SF1CC2CA  2022.03     512.511        NaN      F  Dollars
# 492     BDCQ.SF1CC2CA  2022.06     527.968        NaN      F  Dollars
# 493     BDCQ.SF1CC2CA  2022.09     537.211        NaN      F  Dollars
# 494     BDCQ.SF1CC2CS  2016.06     586.399        NaN      R  Dollars
# 495     BDCQ.SF1CC2CS  2016.09     577.941        NaN      R  Dollars
# 496     BDCQ.SF1CC2CS  2016.12     571.523        NaN      R  Dollars
# 497     BDCQ.SF1CC2CS  2017.03     572.279        NaN      R  Dollars
# 498     BDCQ.SF1CC2CS  2017.06     553.194        NaN      R  Dollars
# 499     BDCQ.SF1CC2CS  2017.09     541.030        NaN      R  Dollars
# 500     BDCQ.SF1CC2CS  2017.12     592.754        NaN      R  Dollars
# 501     BDCQ.SF1CC2CS  2018.03     530.018        NaN      R  Dollars
# 502     BDCQ.SF1CC2CS  2018.06     556.048        NaN      R  Dollars
# 503     BDCQ.SF1CC2CS  2018.09     541.341        NaN      R  Dollars
# 504     BDCQ.SF1CC2CS  2018.12     565.895        NaN      R  Dollars
# 505     BDCQ.SF1CC2CS  2019.03     527.250        NaN      R  Dollars
# 506     BDCQ.SF1CC2CS  2019.06     549.739        NaN      R  Dollars
# 507     BDCQ.SF1CC2CS  2019.09     524.132        NaN      R  Dollars
# 508     BDCQ.SF1CC2CS  2019.12     516.651        NaN      R  Dollars
# 509     BDCQ.SF1CC2CS  2020.03     444.847        NaN      R  Dollars
# 510     BDCQ.SF1CC2CS  2020.06     348.318        NaN      R  Dollars
# 511     BDCQ.SF1CC2CS  2020.09     503.119        NaN      R  Dollars
# 512     BDCQ.SF1CC2CS  2020.12     475.924        NaN      R  Dollars
# 513     BDCQ.SF1CC2CS  2021.03     468.887        NaN      R  Dollars
# 514     BDCQ.SF1CC2CS  2021.06     490.221        NaN      R  Dollars
# 515     BDCQ.SF1CC2CS  2021.09     451.072        NaN      R  Dollars
# 516     BDCQ.SF1CC2CS  2021.12     529.063        NaN      R  Dollars
# 517     BDCQ.SF1CC2CS  2022.03     512.511        NaN      R  Dollars
# 518     BDCQ.SF1CC2CS  2022.06     527.968        NaN      R  Dollars
# 519     BDCQ.SF1CC2CS  2022.09     537.211        NaN      F  Dollars
# 520     BDCQ.SF1CC2CT  2016.06     593.634        NaN      R  Dollars
# 521     BDCQ.SF1CC2CT  2016.09     575.830        NaN      R  Dollars
# 522     BDCQ.SF1CC2CT  2016.12     573.883        NaN      R  Dollars
# 523     BDCQ.SF1CC2CT  2017.03     568.330        NaN      R  Dollars
# 524     BDCQ.SF1CC2CT  2017.06     551.720        NaN      R  Dollars
# 525     BDCQ.SF1CC2CT  2017.09     555.334        NaN      R  Dollars
# 526     BDCQ.SF1CC2CT  2017.12     559.071        NaN      R  Dollars
# 527     BDCQ.SF1CC2CT  2018.03     551.475        NaN      R  Dollars
# 528     BDCQ.SF1CC2CT  2018.06     541.409        NaN      R  Dollars
# 529     BDCQ.SF1CC2CT  2018.09     554.739        NaN      R  Dollars
# 530     BDCQ.SF1CC2CT  2018.12     549.243        NaN      R  Dollars
# 531     BDCQ.SF1CC2CT  2019.03     544.400        NaN      R  Dollars
# 532     BDCQ.SF1CC2CT  2019.06     536.856        NaN      R  Dollars
# 533     BDCQ.SF1CC2CT  2019.09     534.969        NaN      R  Dollars
# 534     BDCQ.SF1CC2CT  2019.12     499.134        NaN      R  Dollars
# 535     BDCQ.SF1CC2CT  2020.03         NaN        NaN      C  Dollars
# 536     BDCQ.SF1CC2CT  2020.06         NaN        NaN      C  Dollars
# 537     BDCQ.SF1CC2CT  2020.09         NaN        NaN      C  Dollars
# 538     BDCQ.SF1CC2CT  2020.12         NaN        NaN      C  Dollars
# 539     BDCQ.SF1CC2CT  2021.03         NaN        NaN      C  Dollars
# 540     BDCQ.SF1CC2CT  2021.06         NaN        NaN      C  Dollars
# 541     BDCQ.SF1CC2CT  2021.09         NaN        NaN      C  Dollars
# 542     BDCQ.SF1CC2CT  2021.12         NaN        NaN      C  Dollars
# 543     BDCQ.SF1CC2CT  2022.03         NaN        NaN      C  Dollars
# 544     BDCQ.SF1CC2CT  2022.06         NaN        NaN      C  Dollars
# 545     BDCQ.SF1CC2CT  2022.09         NaN        NaN      C  Dollars
# 546     BDCQ.SF1CC3CA  2016.06    2247.710        NaN      F  Dollars
# 547     BDCQ.SF1CC3CA  2016.09    2216.005        NaN      F  Dollars
# 548     BDCQ.SF1CC3CA  2016.12    2201.123        NaN      F  Dollars
# 549     BDCQ.SF1CC3CA  2017.03    2063.277        NaN      F  Dollars
# 550     BDCQ.SF1CC3CA  2017.06    2242.174        NaN      F  Dollars
# 551     BDCQ.SF1CC3CA  2017.09    2279.911        NaN      F  Dollars
# 552     BDCQ.SF1CC3CA  2017.12    2361.189        NaN      F  Dollars
# 553     BDCQ.SF1CC3CA  2018.03    2229.447        NaN      F  Dollars
# 554     BDCQ.SF1CC3CA  2018.06    2412.505        NaN      F  Dollars
# 555     BDCQ.SF1CC3CA  2018.09    2449.281        NaN      F  Dollars
# 556     BDCQ.SF1CC3CA  2018.12    2429.150        NaN      F  Dollars
# 557     BDCQ.SF1CC3CA  2019.03    2175.696        NaN      F  Dollars
# 558     BDCQ.SF1CC3CA  2019.06    2428.645        NaN      F  Dollars
# 559     BDCQ.SF1CC3CA  2019.09    2409.721        NaN      F  Dollars
# 560     BDCQ.SF1CC3CA  2019.12    2345.636        NaN      F  Dollars
# 561     BDCQ.SF1CC3CA  2020.03    2247.182        NaN      F  Dollars
# 562     BDCQ.SF1CC3CA  2020.06    1963.658        NaN      F  Dollars
# 563     BDCQ.SF1CC3CA  2020.09    2421.896        NaN      F  Dollars
# 564     BDCQ.SF1CC3CA  2020.12    2480.628        NaN      F  Dollars
# 565     BDCQ.SF1CC3CA  2021.03    2324.697        NaN      F  Dollars
# 566     BDCQ.SF1CC3CA  2021.06    2672.617        NaN      F  Dollars
# 567     BDCQ.SF1CC3CA  2021.09    2537.622        NaN      F  Dollars
# 568     BDCQ.SF1CC3CA  2021.12    2818.490        NaN      F  Dollars
# 569     BDCQ.SF1CC3CA  2022.03    2692.666        NaN      R  Dollars
# 570     BDCQ.SF1CC3CA  2022.06    3061.314        NaN      R  Dollars
# 571     BDCQ.SF1CC3CA  2022.09    3020.923        NaN      F  Dollars
# 572     BDCQ.SF1CC3CS  2016.06    2211.577        NaN      R  Dollars
# 573     BDCQ.SF1CC3CS  2016.09    2169.226        NaN      R  Dollars
# 574     BDCQ.SF1CC3CS  2016.12    2156.129        NaN      R  Dollars
# 575     BDCQ.SF1CC3CS  2017.03    2196.033        NaN      R  Dollars
# 576     BDCQ.SF1CC3CS  2017.06    2197.951        NaN      R  Dollars
# 577     BDCQ.SF1CC3CS  2017.09    2232.637        NaN      R  Dollars
# 578     BDCQ.SF1CC3CS  2017.12    2320.574        NaN      R  Dollars
# 579     BDCQ.SF1CC3CS  2018.03    2374.727        NaN      R  Dollars
# 580     BDCQ.SF1CC3CS  2018.06    2353.516        NaN      R  Dollars
# 581     BDCQ.SF1CC3CS  2018.09    2399.999        NaN      R  Dollars
# 582     BDCQ.SF1CC3CS  2018.12    2396.924        NaN      R  Dollars
# 583     BDCQ.SF1CC3CS  2019.03    2317.928        NaN      R  Dollars
# 584     BDCQ.SF1CC3CS  2019.06    2357.056        NaN      R  Dollars
# 585     BDCQ.SF1CC3CS  2019.09    2365.217        NaN      R  Dollars
# 586     BDCQ.SF1CC3CS  2019.12    2321.170        NaN      R  Dollars
# 587     BDCQ.SF1CC3CS  2020.03    2395.770        NaN      R  Dollars
# 588     BDCQ.SF1CC3CS  2020.06    1896.136        NaN      R  Dollars
# 589     BDCQ.SF1CC3CS  2020.09    2381.648        NaN      R  Dollars
# 590     BDCQ.SF1CC3CS  2020.12    2461.707        NaN      R  Dollars
# 591     BDCQ.SF1CC3CS  2021.03    2477.914        NaN      R  Dollars
# 592     BDCQ.SF1CC3CS  2021.06    2569.770        NaN      R  Dollars
# 593     BDCQ.SF1CC3CS  2021.09    2501.622        NaN      R  Dollars
# 594     BDCQ.SF1CC3CS  2021.12    2801.384        NaN      R  Dollars
# 595     BDCQ.SF1CC3CS  2022.03    2868.753        NaN      R  Dollars
# 596     BDCQ.SF1CC3CS  2022.06    2935.616        NaN      R  Dollars
# 597     BDCQ.SF1CC3CS  2022.09    2984.331        NaN      F  Dollars
# 598     BDCQ.SF1CC3CT  2016.06    2194.688        NaN      R  Dollars
# 599     BDCQ.SF1CC3CT  2016.09    2176.139        NaN      R  Dollars
# 600     BDCQ.SF1CC3CT  2016.12    2164.553        NaN      R  Dollars
# 601     BDCQ.SF1CC3CT  2017.03    2184.157        NaN      R  Dollars
# 602     BDCQ.SF1CC3CT  2017.06    2201.643        NaN      R  Dollars
# 603     BDCQ.SF1CC3CT  2017.09    2240.532        NaN      R  Dollars
# 604     BDCQ.SF1CC3CT  2017.12    2317.237        NaN      R  Dollars
# 605     BDCQ.SF1CC3CT  2018.03    2361.170        NaN      R  Dollars
# 606     BDCQ.SF1CC3CT  2018.06    2372.630        NaN      R  Dollars
# 607     BDCQ.SF1CC3CT  2018.09    2393.325        NaN      R  Dollars
# 608     BDCQ.SF1CC3CT  2018.12    2380.740        NaN      R  Dollars
# 609     BDCQ.SF1CC3CT  2019.03    2343.123        NaN      R  Dollars
# 610     BDCQ.SF1CC3CT  2019.06    2347.668        NaN      R  Dollars
# 611     BDCQ.SF1CC3CT  2019.09    2351.112        NaN      R  Dollars
# 612     BDCQ.SF1CC3CT  2019.12    2346.855        NaN      R  Dollars
# 613     BDCQ.SF1CC3CT  2020.03         NaN        NaN      C  Dollars
# 614     BDCQ.SF1CC3CT  2020.06         NaN        NaN      C  Dollars
# 615     BDCQ.SF1CC3CT  2020.09         NaN        NaN      C  Dollars
# 616     BDCQ.SF1CC3CT  2020.12         NaN        NaN      C  Dollars
# 617     BDCQ.SF1CC3CT  2021.03         NaN        NaN      C  Dollars
# 618     BDCQ.SF1CC3CT  2021.06         NaN        NaN      C  Dollars
# 619     BDCQ.SF1CC3CT  2021.09         NaN        NaN      C  Dollars
# 620     BDCQ.SF1CC3CT  2021.12         NaN        NaN      C  Dollars
# 621     BDCQ.SF1CC3CT  2022.03         NaN        NaN      C  Dollars
# 622     BDCQ.SF1CC3CT  2022.06         NaN        NaN      C  Dollars
# 623     BDCQ.SF1CC3CT  2022.09         NaN        NaN      C  Dollars
# 624     BDCQ.SF1CC4CA  2016.06     378.816        NaN      F  Dollars
# 625     BDCQ.SF1CC4CA  2016.09     382.970        NaN      F  Dollars
# 626     BDCQ.SF1CC4CA  2016.12     439.040        NaN      F  Dollars
# 627     BDCQ.SF1CC4CA  2017.03     339.726        NaN      F  Dollars
# 628     BDCQ.SF1CC4CA  2017.06     363.012        NaN      F  Dollars
# 629     BDCQ.SF1CC4CA  2017.09     379.748        NaN      F  Dollars
# 630     BDCQ.SF1CC4CA  2017.12     403.359        NaN      F  Dollars
# 631     BDCQ.SF1CC4CA  2018.03     345.957        NaN      F  Dollars
# 632     BDCQ.SF1CC4CA  2018.06     370.112        NaN      F  Dollars
# 633     BDCQ.SF1CC4CA  2018.09     385.258        NaN      F  Dollars
# 634     BDCQ.SF1CC4CA  2018.12     407.693        NaN      F  Dollars
# 635     BDCQ.SF1CC4CA  2019.03     345.400        NaN      F  Dollars
# 636     BDCQ.SF1CC4CA  2019.06     364.445        NaN      F  Dollars
# 637     BDCQ.SF1CC4CA  2019.09     386.209        NaN      F  Dollars
# 638     BDCQ.SF1CC4CA  2019.12     409.094        NaN      F  Dollars
# 639     BDCQ.SF1CC4CA  2020.03     327.183        NaN      F  Dollars
# 640     BDCQ.SF1CC4CA  2020.06     257.649        NaN      F  Dollars
# 641     BDCQ.SF1CC4CA  2020.09     353.746        NaN      F  Dollars
# 642     BDCQ.SF1CC4CA  2020.12     384.357        NaN      F  Dollars
# 643     BDCQ.SF1CC4CA  2021.03     315.953        NaN      F  Dollars
# 644     BDCQ.SF1CC4CA  2021.06     355.379        NaN      F  Dollars
# 645     BDCQ.SF1CC4CA  2021.09     338.601        NaN      F  Dollars
# 646     BDCQ.SF1CC4CA  2021.12     387.874        NaN      F  Dollars
# 647     BDCQ.SF1CC4CA  2022.03     316.165        NaN      F  Dollars
# 648     BDCQ.SF1CC4CA  2022.06     373.898        NaN      F  Dollars
# 649     BDCQ.SF1CC4CA  2022.09     399.209        NaN      F  Dollars
# 650     BDCQ.SF1CC4CS  2016.06     389.918        NaN      R  Dollars
# 651     BDCQ.SF1CC4CS  2016.09     380.086        NaN      R  Dollars
# 652     BDCQ.SF1CC4CS  2016.12     400.085        NaN      R  Dollars
# 653     BDCQ.SF1CC4CS  2017.03     369.421        NaN      R  Dollars
# 654     BDCQ.SF1CC4CS  2017.06     372.650        NaN      R  Dollars
# 655     BDCQ.SF1CC4CS  2017.09     375.012        NaN      R  Dollars
# ...
# 5832           Unadjusted             NaN
# 5833           Unadjusted             NaN
# 5834           Unadjusted             NaN
# 5835           Unadjusted             NaN
# 5836           Unadjusted             NaN
# 5837           Unadjusted             NaN
# 5838           Unadjusted             NaN
# 5839           Unadjusted             NaN
# 5840           Unadjusted             NaN
# 5841           Unadjusted             NaN
# 5842           Unadjusted             NaN
# 5843           Unadjusted             NaN
# 5844           Unadjusted             NaN
# 5845           Unadjusted             NaN
# 5846           Unadjusted             NaN
# 5847           Unadjusted             NaN
# 5848           Unadjusted             NaN
# 5849           Unadjusted             NaN
# 5850           Unadjusted             NaN
# 5851           Unadjusted             NaN
# 5852           Unadjusted             NaN
# 5853           Unadjusted             NaN
# 5854           Unadjusted             NaN
# 5855           Unadjusted             NaN
# 5856           Unadjusted             NaN
# 5857           Unadjusted             NaN
# 5858           Unadjusted             NaN
# 5859           Unadjusted             NaN
# 5860           Unadjusted             NaN
# 5861           Unadjusted             NaN
# 5862           Unadjusted             NaN
# 5863           Unadjusted             NaN
# 5864           Unadjusted             NaN
# 5865           Unadjusted             NaN
# 5866           Unadjusted             NaN
# 5867           Unadjusted             NaN
# 5868           Unadjusted             NaN
# 5869           Unadjusted             NaN
# 5870           Unadjusted             NaN
# 5871           Unadjusted             NaN
# 5872           Unadjusted             NaN
# 5873           Unadjusted             NaN
# 5874           Unadjusted             NaN
# 5875           Unadjusted             NaN
# 5876           Unadjusted             NaN
# 5877           Unadjusted             NaN
# 5878           Unadjusted             NaN
# 5879           Unadjusted             NaN
# 5880           Unadjusted             NaN
# 5881           Unadjusted             NaN
# 5882           Unadjusted             NaN
# 5883           Unadjusted             NaN
# 5884           Unadjusted             NaN
# 5885           Unadjusted             NaN
# 5886           Unadjusted             NaN
# 5887           Unadjusted             NaN
# 5888           Unadjusted             NaN
# 5889           Unadjusted             NaN
# 5890           Unadjusted             NaN
# 5891           Unadjusted             NaN
# 5892           Unadjusted             NaN
# 5893           Unadjusted             NaN
# 5894           Unadjusted             NaN
# 5895           Unadjusted             NaN
# 5896           Unadjusted             NaN
# 5897           Unadjusted             NaN
# 5898           Unadjusted             NaN
# 5899           Unadjusted             NaN
# 5900           Unadjusted             NaN
# 5901           Unadjusted             NaN
# 5902           Unadjusted             NaN
# 5903           Unadjusted             NaN
# 5904           Unadjusted             NaN
# 5905           Unadjusted             NaN
# 5906           Unadjusted             NaN
# 5907           Unadjusted             NaN
# 5908           Unadjusted             NaN
# 5909           Unadjusted             NaN
# 5910           Unadjusted             NaN
# 5911           Unadjusted             NaN
# 5912           Unadjusted             NaN
# 5913           Unadjusted             NaN
# 5914           Unadjusted             NaN
# 5915           Unadjusted             NaN
# 5916           Unadjusted             NaN
# 5917           Unadjusted             NaN
# 5918           Unadjusted             NaN
# 5919           Unadjusted             NaN
# 5920           Unadjusted             NaN
# 5921           Unadjusted             NaN
# 5922           Unadjusted             NaN
# 5923           Unadjusted             NaN
# 5924           Unadjusted             NaN
# 5925           Unadjusted             NaN
# 5926           Unadjusted             NaN
# 5927           Unadjusted             NaN
# 5928           Unadjusted             NaN
# 5929           Unadjusted             NaN
# 5930           Unadjusted             NaN
# 5931           Unadjusted             NaN
# 5932           Unadjusted             NaN
# 5933           Unadjusted             NaN
# 5934           Unadjusted             NaN
# 5935           Unadjusted             NaN
# 5936           Unadjusted             NaN
# 5937           Unadjusted             NaN
# 5938           Unadjusted             NaN
# 5939           Unadjusted             NaN
# 5940           Unadjusted             NaN
# 5941           Unadjusted             NaN
# 5942           Unadjusted             NaN
# 5943           Unadjusted             NaN
# 5944           Unadjusted             NaN
# 5945           Unadjusted             NaN
# 5946           Unadjusted             NaN
# 5947           Unadjusted             NaN
# 5948           Unadjusted             NaN
# 5949           Unadjusted             NaN
# 5950           Unadjusted             NaN
# 5951           Unadjusted             NaN
# 5952           Unadjusted             NaN
# 5953           Unadjusted             NaN
# 5954           Unadjusted             NaN
# 5955           Unadjusted             NaN
# 5956           Unadjusted             NaN
# 5957           Unadjusted             NaN
# 5958           Unadjusted             NaN
# 5959           Unadjusted             NaN
# 5960           Unadjusted             NaN
# 5961           Unadjusted             NaN
# 5962           Unadjusted             NaN
# 5963           Unadjusted             NaN
# 5964           Unadjusted             NaN
# 5965           Unadjusted             NaN
# 5966           Unadjusted             NaN
# 5967           Unadjusted             NaN
# 5968           Unadjusted             NaN
# 5969           Unadjusted             NaN
# 5970           Unadjusted             NaN
# 5971           Unadjusted             NaN
# 5972           Unadjusted             NaN
# 5973           Unadjusted             NaN
# 5974           Unadjusted             NaN
# 5975           Unadjusted             NaN
# 5976           Unadjusted             NaN
# 5977           Unadjusted             NaN
# 5978           Unadjusted             NaN
# 5979           Unadjusted             NaN
# 5980           Unadjusted             NaN
# 5981           Unadjusted             NaN
# 5982           Unadjusted             NaN
# 5983           Unadjusted             NaN
# 5984           Unadjusted             NaN
# 5985           Unadjusted             NaN
# 5986           Unadjusted             NaN
# 5987           Unadjusted             NaN
# 5988           Unadjusted             NaN
# 5989           Unadjusted             NaN
# 5990           Unadjusted             NaN
# 5991           Unadjusted             NaN
# 5992           Unadjusted             NaN
# 5993           Unadjusted             NaN
# 5994           Unadjusted             NaN
# 5995           Unadjusted             NaN
# 5996           Unadjusted             NaN
# 5997           Unadjusted             NaN
# 5998           Unadjusted             NaN
# 5999           Unadjusted             NaN
# 6000           Unadjusted             NaN
# 6001           Unadjusted             NaN
# 6002           Unadjusted             NaN
# 6003           Unadjusted             NaN
# 6004           Unadjusted             NaN
# 6005           Unadjusted             NaN
# 6006           Unadjusted             NaN
# 6007           Unadjusted             NaN
# 6008           Unadjusted             NaN
# 6009           Unadjusted             NaN
# 6010           Unadjusted             NaN
# 6011           Unadjusted             NaN
# 6012           Unadjusted             NaN
# 6013           Unadjusted             NaN
# 6014           Unadjusted             NaN
# 6015           Unadjusted             NaN
# 6016           Unadjusted             NaN
# 6017           Unadjusted             NaN
# 6018           Unadjusted             NaN
# 6019           Unadjusted             NaN
# 6020           Unadjusted             NaN
# 6021           Unadjusted             NaN
# 6022           Unadjusted             NaN
# 6023           Unadjusted             NaN
# 6024           Unadjusted             NaN
# 6025           Unadjusted             NaN
# 6026           Unadjusted             NaN
# 6027           Unadjusted             NaN
# 6028           Unadjusted             NaN
# 6029           Unadjusted             NaN
# 6030           Unadjusted             NaN
# 6031           Unadjusted             NaN
# 6032           Unadjusted             NaN
# 6033           Unadjusted             NaN
# 6034           Unadjusted             NaN
# 6035           Unadjusted             NaN
# 6036           Unadjusted             NaN
# 6037           Unadjusted             NaN
# 6038           Unadjusted             NaN
# 6039           Unadjusted             NaN
# 6040           Unadjusted             NaN
# 6041           Unadjusted             NaN
# 6042           Unadjusted             NaN
# 6043           Unadjusted             NaN
# 6044           Unadjusted             NaN
# 6045           Unadjusted             NaN
# 6046           Unadjusted             NaN
# 6047           Unadjusted             NaN
# 6048           Unadjusted             NaN
# 6049           Unadjusted             NaN
# 6050           Unadjusted             NaN
# 6051           Unadjusted             NaN
# 6052           Unadjusted             NaN
# 6053           Unadjusted             NaN
# 6054           Unadjusted             NaN
# 6055           Unadjusted             NaN
# 6056           Unadjusted             NaN
# 6057           Unadjusted             NaN
# 6058           Unadjusted             NaN
# 6059           Unadjusted             NaN
# 6060           Unadjusted             NaN
# 6061           Unadjusted             NaN
# 6062           Unadjusted             NaN
# 6063           Unadjusted             NaN
# 6064           Unadjusted             NaN
# 6065           Unadjusted             NaN
# 6066           Unadjusted             NaN
# 6067           Unadjusted             NaN
# 6068           Unadjusted             NaN
# 6069           Unadjusted             NaN
# 6070           Unadjusted             NaN
# 6071           Unadjusted             NaN
# 6072           Unadjusted             NaN
# 6073           Unadjusted             NaN
# 6074           Unadjusted             NaN
# 6075           Unadjusted             NaN
# 6076           Unadjusted             NaN
# 6077           Unadjusted             NaN
# 6078           Unadjusted             NaN
# 6079           Unadjusted             NaN
# 6080           Unadjusted             NaN
# 6081           Unadjusted             NaN
# 6082           Unadjusted             NaN
# 6083           Unadjusted             NaN
# 6084           Unadjusted             NaN
# 6085           Unadjusted             NaN
# 6086           Unadjusted             NaN
# 6087           Unadjusted             NaN
# 6088           Unadjusted             NaN
# 6089           Unadjusted             NaN
# 6090           Unadjusted             NaN
# 6091           Unadjusted             NaN
# 6092           Unadjusted             NaN
# 6093           Unadjusted             NaN
# 6094           Unadjusted             NaN
# 6095           Unadjusted             NaN
# 6096           Unadjusted             NaN
# 6097           Unadjusted             NaN
# 6098           Unadjusted             NaN
# 6099           Unadjusted             NaN
# 6100           Unadjusted             NaN
# 6101           Unadjusted             NaN
# 6102           Unadjusted             NaN
# 6103           Unadjusted             NaN
# 6104           Unadjusted             NaN
# 6105           Unadjusted             NaN
# 6106           Unadjusted             NaN
# 6107           Unadjusted             NaN
# 6108           Unadjusted             NaN
# 6109           Unadjusted             NaN
# 6110           Unadjusted             NaN
# 6111           Unadjusted             NaN
# 6112           Unadjusted             NaN
# 6113           Unadjusted             NaN
# 6114           Unadjusted             NaN
# 6115           Unadjusted             NaN
# 6116           Unadjusted             NaN
# 6117           Unadjusted             NaN
# 6118           Unadjusted             NaN
# 6119           Unadjusted             NaN
# 6120           Unadjusted             NaN
# 6121           Unadjusted             NaN
# 6122           Unadjusted             NaN
# 6123           Unadjusted             NaN
# 6124           Unadjusted             NaN
# 6125           Unadjusted             NaN
# 6126           Unadjusted             NaN
# 6127           Unadjusted             NaN
# 6128           Unadjusted             NaN
# 6129           Unadjusted             NaN
# 6130           Unadjusted             NaN
# 6131           Unadjusted             NaN
# 6132           Unadjusted             NaN
# 6133           Unadjusted             NaN
# 6134           Unadjusted             NaN
# 6135           Unadjusted             NaN
# 6136           Unadjusted             NaN
# 6137           Unadjusted             NaN
# 6138           Unadjusted             NaN
# 6139           Unadjusted             NaN
# 6140           Unadjusted             NaN
# 6141           Unadjusted             NaN
# 6142           Unadjusted             NaN
# 6143           Unadjusted             NaN
# 6144           Unadjusted             NaN
# 6145           Unadjusted             NaN
# 6146           Unadjusted             NaN
# 6147           Unadjusted             NaN
# 6148           Unadjusted             NaN
# 6149           Unadjusted             NaN
# 6150           Unadjusted             NaN
# 6151           Unadjusted             NaN
# 6152           Unadjusted             NaN
# 6153           Unadjusted             NaN
# 6154           Unadjusted             NaN
# 6155           Unadjusted             NaN
# 6156           Unadjusted             NaN
# 6157           Unadjusted             NaN
# 6158           Unadjusted             NaN
# 6159           Unadjusted             NaN
# 6160           Unadjusted             NaN
# 6161           Unadjusted             NaN
# 6162           Unadjusted             NaN
# 6163           Unadjusted             NaN
# 6164           Unadjusted             NaN
# 6165           Unadjusted             NaN
# 6166           Unadjusted             NaN
# 6167           Unadjusted             NaN
# 6168           Unadjusted             NaN
# 6169           Unadjusted             NaN
# 6170           Unadjusted             NaN
# 6171           Unadjusted             NaN
# 6172           Unadjusted             NaN
# 6173           Unadjusted             NaN
# 6174           Unadjusted             NaN
# 6175           Unadjusted             NaN
# 6176           Unadjusted             NaN
# 6177           Unadjusted             NaN
# 6178           Unadjusted             NaN
# 6179           Unadjusted             NaN
# 6180           Unadjusted             NaN
# 6181           Unadjusted             NaN
# 6182           Unadjusted             NaN
# 6183           Unadjusted             NaN
# 6184           Unadjusted             NaN
# 6185           Unadjusted             NaN
# 6186           Unadjusted             NaN
# 6187           Unadjusted             NaN
# 6188           Unadjusted             NaN
# 6189           Unadjusted             NaN
# 6190           Unadjusted             NaN
# 6191           Unadjusted             NaN
# 6192           Unadjusted             NaN
# 6193           Unadjusted             NaN
# 6194           Unadjusted             NaN

# %% [markdown]
# **4.3 Read a CSV file and print the first few rows using the ```head()``` method:**
# - Using the pandas library in Python to read a CSV file and print the first five rows using the ```head()``` method.
# - This code would load the file into a pandas dataframe and print the first five rows to the console.
# - You can adjust the number of rows displayed by changing the argument of the ```head() method, e.g. df.head(10)``` would display the first ten rows.

# %%
import pandas as pd

# Read the CSV file into a pandas dataframe
df = pd.read_csv('Images/largedata.csv')

# Print the first 10 rows of the dataframe
print(df.head(10))
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0    BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars          6
# 1    BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars          6
# 2    BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars          6
# 3    BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars          6
# 4    BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars          6
# 5    BDCQ.SF1AA2CA  2017.09    1282.436        NaN      F  Dollars          6
# 6    BDCQ.SF1AA2CA  2017.12    1290.820        NaN      F  Dollars          6
# 7    BDCQ.SF1AA2CA  2018.03    1412.007        NaN      F  Dollars          6
# 8    BDCQ.SF1AA2CA  2018.06    1488.055        NaN      F  Dollars          6
# 9    BDCQ.SF1AA2CA  2018.09    1497.678        NaN      F  Dollars          6
#
#                           Subject  \
# 0  Business Data Collection - BDC
# 1  Business Data Collection - BDC
# 2  Business Data Collection - BDC
# 3  Business Data Collection - BDC
# 4  Business Data Collection - BDC
# 5  Business Data Collection - BDC
# 6  Business Data Collection - BDC
# 7  Business Data Collection - BDC
# 8  Business Data Collection - BDC
# 9  Business Data Collection - BDC
#
#                                              Group            Series_title_1  \
# 0  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 1  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 2  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 3  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 4  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 5  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 6  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 7  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 8  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 9  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
#
#          Series_title_2  Series_title_3 Series_title_4  Series_title_5
# 0  Forestry and Logging  Current prices     Unadjusted             NaN
# 1  Forestry and Logging  Current prices     Unadjusted             NaN
# 2  Forestry and Logging  Current prices     Unadjusted             NaN
# 3  Forestry and Logging  Current prices     Unadjusted             NaN
# 4  Forestry and Logging  Current prices     Unadjusted             NaN
# 5  Forestry and Logging  Current prices     Unadjusted             NaN
# 6  Forestry and Logging  Current prices     Unadjusted             NaN
# 7  Forestry and Logging  Current prices     Unadjusted             NaN
# 8  Forestry and Logging  Current prices     Unadjusted             NaN
# 9  Forestry and Logging  Current prices     Unadjusted             NaN

# %% [markdown]
# **4.4 Read a CSV file and print the Last few rows using the ```tail()``` method:**
# - The code would load the file into a pandas dataframe and print the last five rows to the console using the ```tail()``` method..
# - You can adjust the number of rows displayed by changing the argument of the ```tail() method, e.g. df.tail(10)``` would display the last ten rows.

# %%
import pandas as pd

# Read the CSV file into a pandas dataframe
df = pd.read_csv('Images/largedata.csv')

# Print the last five rows of the dataframe
print(df.tail())
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 6190     BDCQ.SF8RSCA  2021.09     382.195        NaN      F  Dollars
# 6191     BDCQ.SF8RSCA  2021.12     397.184        NaN      F  Dollars
# 6192     BDCQ.SF8RSCA  2022.03     493.945        NaN      F  Dollars
# 6193     BDCQ.SF8RSCA  2022.06     579.955        NaN      R  Dollars
# 6194     BDCQ.SF8RSCA  2022.09     609.161        NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 6190          6  Business Data Collection - BDC
# 6191          6  Business Data Collection - BDC
# 6192          6  Business Data Collection - BDC
# 6193          6  Business Data Collection - BDC
# 6194          6  Business Data Collection - BDC
#
#                                                 Group    Series_title_1  \
# 6190  Industry by financial variable (NZSIOC Level 1)  Operating profit
# 6191  Industry by financial variable (NZSIOC Level 1)  Operating profit
# 6192  Industry by financial variable (NZSIOC Level 1)  Operating profit
# 6193  Industry by financial variable (NZSIOC Level 1)  Operating profit
# 6194  Industry by financial variable (NZSIOC Level 1)  Operating profit
#
#                            Series_title_2 Series_title_3 Series_title_4  \
# 6190  Arts, Recreation and Other Services        Current     Unadjusted
# 6191  Arts, Recreation and Other Services        Current     Unadjusted
# 6192  Arts, Recreation and Other Services        Current     Unadjusted
# 6193  Arts, Recreation and Other Services        Current     Unadjusted
# 6194  Arts, Recreation and Other Services        Current     Unadjusted
#
#       Series_title_5
# 6190             NaN
# 6191             NaN
# 6192             NaN
# 6193             NaN
# 6194             NaN

# %% [markdown]
# **4.5 Pandas ```describe()``` method on CSV Files**

# %% [markdown]
# - The ```describe()``` method returns description of the data in the DataFrame.
# - If the DataFrame contains numerical data, the description contains these information for each column: <br>
# ```count``` - The number of not-empty values. <br>
# ```mean``` - The average (mean) value.

# %%
# importing pandas module
import pandas as pd
  
# importing regex module
import re
  
# making data frame
data = pd.read_csv('Images/nba.csv')

  
# removing null values to avoid errors
data.dropna(inplace=True)
  
# list of dtypes to include
include = ['object', 'float', 'int']
  
# calling describe method
desc = data.describe(include=include)
  
# display
desc
# Out:
#               Name                  Team      Number Position         Age  \
# count          364                   364  364.000000      364  364.000000
# unique         364                    30         NaN        5         NaN
# top     Jeff Green  New Orleans Pelicans         NaN       SG         NaN
# freq             1                    16         NaN       87         NaN
# mean           NaN                   NaN   16.829670      NaN   26.615385
# std            NaN                   NaN   14.994162      NaN    4.233591
# min            NaN                   NaN    0.000000      NaN   19.000000
# 25%            NaN                   NaN    5.000000      NaN   24.000000
# 50%            NaN                   NaN   12.000000      NaN   26.000000
# 75%            NaN                   NaN   25.000000      NaN   29.000000
# max            NaN                   NaN   99.000000      NaN   40.000000
#
#        Height      Weight   College        Salary
# count     364  364.000000       364  3.640000e+02
# unique     17         NaN       115           NaN
# top       6-9         NaN  Kentucky           NaN
# freq       49         NaN        22           NaN
# mean      NaN  219.785714       NaN  4.620311e+06
# std       NaN   24.793099       NaN  5.119716e+06
# min       NaN  161.000000       NaN  5.572200e+04
# 25%       NaN  200.000000       NaN  1.000000e+06
# 50%       NaN  220.000000       NaN  2.515440e+06
# 75%       NaN  240.000000       NaN  6.149694e+06
# max       NaN  279.000000       NaN  2.287500e+07

# %% [markdown]
# **4.6 Writing a Pandas DataFrame to CSV file**
#
# To write a Pandas DataFrame to CSV file, we can take the following Steps:
#
# - Create a two-dimensional, size-mutable, potentially heterogeneous tabular data, df.
# - Print the input DataFrame.
# - Use ```df.to_csv``` to save the values of the DataFrame to a CSV (comma-separated values) file.

# %%
import pandas as pd
# Create  DataFrame with below sample values
df = pd.DataFrame(
   {
      "x": [5, 2, 1, 9],
      "y": [4, 1, 5, 10],
      "z": [4, 1, 5, 0]
   }
)

# Write  DataFrame into CSV File
print ("Input DataFrame is:\n", df)
df.to_csv("Images\\test.csv", sep=',')

# Read from CSV to DataFrame
df_csv = pd.read_csv("Images\\test.csv")
print ("CSV DataFrame is:\n", df_csv)
# Out:
# Input DataFrame is:
#     x   y  z
# 0  5   4  4
# 1  2   1  1
# 2  1   5  5
# 3  9  10  0
# CSV DataFrame is:
#     Unnamed: 0  x   y  z
# 0           0  5   4  4
# 1           1  2   1  1
# 2           2  1   5  5
# 3           3  9  10  0

# %% [markdown]
# <hr>

# %% [markdown]
# ## 5. Read Excel in Pandas
#
# - A simple way to store big data sets with FORMAT RICH Features is to use xls files (Excel Format files).
#
# **Difference between CSV and XLS file formats**<br>
# *The CSV format is a plain text format in which values are separated by commas (Comma Separated Values), while XLS file format is an Excel Sheets binary file format which holds information about all the worksheets in a file, including both content and formatting.
# CSV files contains plain text and is a well known format that can be read by everyone including Pandas.*

# %% [markdown]
# **5.1 Install xlrd**<br>
#
# Pandas ```.read_excel``` uses a library called ```xlrd``` internally.
#
# - ```xlrd``` is a library for reading (input) Excel files (.xlsx, .xls) in Python.
#
# - ```xlrd``` can be installed with pip. (pip3 depending on the environment)
#
# > $ pip install xlrd

# %% [markdown]
# **Read excel: Python Example**
#
# - Specify the path or URL of the Excel file in the first argument.
# - If there are multiple sheets, only the first sheet is used by pandas.
# - It reads as DataFrame.

# %%
import pandas as pd

df = pd.read_excel('Images/excel-sample.xlsx')

print(df)
# Out:
#    Student ID First Name Last Name                  Email Enrollment Date
# 0           1       John       Doe     john.doe@email.com      2020-09-01
# 1           2       Jane     Smith   jane.smith@email.com      2020-09-01
# 2           3        Bob   Johnson  bob.johnson@email.com      2020-09-01
# 3           4      Sarah       Lee    sarah.lee@email.com      2020-09-01
# 4           5      David      Wong   david.wong@email.com      2020-09-01

# %% [markdown]
# <br>
# <img src="images/Image-excel.png" alt="Drawing" style="width: 600px;" align="center"/>
# <br>
# <br>

# %% [markdown]
# **5.2 Load multiple sheets**
# - It is also possible to specify a list in the argumentsheet_name.
# - It is OK even if it is a number of 0 starting or the sheet name.
# - The specified number or sheet name is the key key, and the data pandas.
# - The DataFrame is read as the ordered dictionary OrderedDict with the value value.

# %%
import pandas as pd


df_sheet_multi = pd.read_excel('Images/excel-sample.xlsx', sheet_name=[0, 'sheet2'])

print("First Sheet at Index 0:")
print(df_sheet_multi[0])
print("Sheet-2:")
print(df_sheet_multi['sheet2'])

print("Datatype Details:")
print(type(df_sheet_multi))
print(type(df_sheet_multi['sheet2']))
# Out:
# First Sheet at Index 0:
#    Student ID First Name Last Name                  Email Enrollment Date
# 0           1       John       Doe     john.doe@email.com      2020-09-01
# 1           2       Jane     Smith   jane.smith@email.com      2020-09-01
# 2           3        Bob   Johnson  bob.johnson@email.com      2020-09-01
# 3           4      Sarah       Lee    sarah.lee@email.com      2020-09-01
# 4           5      David      Wong   david.wong@email.com      2020-09-01
# Sheet-2:
#    Student ID First Name Last Name  GPA
# 0           1       John       Doe  9.6
# 1           2       Jane     Smith  8.8
# 2           3        Bob   Johnson  7.0
# 3           4      Sarah       Lee  9.1
# 4           5      David      Wong  8.9
# Datatype Details:
# <class 'dict'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# **5.3 Display List of Columns Headers of the Excel Sheet**
# - We can get the list of column headers using the columns property of the dataframe object.

# %%
import pandas as pd


df_sheet_multi = pd.read_excel('Images/excel-sample.xlsx', sheet_name=[0, 'sheet2'])

print("Column Headers of the Excel Sheet:")
print(df_sheet_multi[0].columns.ravel())
# Out:
# Column Headers of the Excel Sheet:
# ['Student ID' 'First Name' 'Last Name' 'Email' 'Enrollment Date']
# <ipython-input-10-44073acc8f4d>:7: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   print(df_sheet_multi[0].columns.ravel())

# %% [markdown]
# **5.4 Pandas ```read_excel() usecols``` example**
# - We can specify the column names to be read from the excel file.
# - It’s useful when you are interested in only a few of the columns of the excel sheet.

# %%
import pandas

excel_data_df = pandas.read_excel('Images/excel-sample.xlsx', sheet_name='sheet2', usecols=['First Name', 'Last Name', 'GPA'])
print(excel_data_df)
# Out:
#   First Name Last Name  GPA
# 0       John       Doe  9.6
# 1       Jane     Smith  8.8
# 2        Bob   Johnson  7.0
# 3      Sarah       Lee  9.1
# 4      David      Wong  8.9

# %% [markdown]
# <hr>

# %% [markdown]
# # Homework Questions

# %% [markdown]
# 1) Create a dataframe for the below array
# ```
#      x = ['Python', 'Pandas','Java']
# ```

# %% [markdown]
# 2) Using Pandas library, create a DataFrame from Series named 's'

# %% [markdown]
# 3) Create a DataFrame from Dict of Series
# ```
#    info1 = {'one' : pd.Series([11, 22, 33, 44, 65], index=['a', 'b', 'c', 'd', 'e']),
#             'two' : pd.Series([11, 62, 73, 43, 25, 46], index=['a', 'b', 'c', 'd', 'e', 'f'])}
# ```

# %% [markdown]
# 4) Load a csv files into dataframe

# %% [markdown]
# 5) Check the max_rows of the csv file

# %% [markdown]
# 6) Increase the maximum number of rows to display the entire DataFrame.

# %% [markdown]
# 7) Write a code to Slice rows from a DataFrame

# %% [markdown]
# 8) Add a new column to an existing DataFrame

# %% [markdown]
# 9) Using Pandas library, delete a column named 'Age' from a DataFrame named 'df'.
# ```
#         data = {'Name': ['John', 'Mike', 'Sara', 'David'],
#         'Age': [25, 30, 28, 35],
#         'Gender': ['Male', 'Male', 'Female', 'Male']}
# ```

# %% [markdown]
# 10) Using Pandas library, select all the rows and columns where 'Age' is greater than 30 in a DataFrame named 'df'.
# ```
#         data = {'Name': ['John', 'Mike', 'Sara', 'David'],
#         'Age': [25, 30, 28, 35],
#         'Gender': ['Male', 'Male', 'Female', 'Male']}
# ```

# %% [markdown]
# 11) Using Pandas library, Read Excel File without Header Row

# %% [markdown]
# 12. Concatenate the following two pandas dataframes:
#    ```
#          Name  Age  Gender
#       0  John   25    Male
#       1  Jane   30  Female
#       2  Mark   20    Male
#    ```
#          and
#
#    ```
#          Name  Age Gender
#       0  Lily
#    ```

# %% [markdown]
# <hr>

# %% [markdown]
# For homework solutions please refer to the ```HomeworkSolutions.ipynb``` file
